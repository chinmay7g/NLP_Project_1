# %%
#loading package

import spacy

nlp = spacy.load('en')

# %%
#laoding data

import wikipedia

def pages_to_sentences(*pages):
    sentences = []
    for page in pages:
        p = wikipedia.page(page)
        doc = nlp(p.content)
        sentences += [sent.text for sent in doc.sents]
    return sentences

greek_sents = pages_to_sentences('Greek Mythology', 'Amazons')
river_sents = pages_to_sentences('Amazon River')
company_sents = pages_to_sentences('Amazon.com,Inc.')

# %%
#creating the data
document = greek_sents + river_sents + company_sents

#creating the labels

labels = ['Greek Mythology']*len(greek_sents) + ['Amazon_River']*len(river_sents) + ['Amazon_Company']*len(company_sents)

# %%
#cross-checking

print(len(greek_sents))
print(greek_sents[30])
print('\n')
print(len(river_sents))
print(river_sents[30])
print('\n')
print(len(company_sents))
print(company_sents[400])
# Out:
# 995
# Hesiod, a possible contemporary with Homer, offers in his  Theogony  (Origin of the Gods) the fullest account of the earliest Greek myths, dealing with the creation of the world; the origin of the gods, Titans, and Giants; as well as elaborate genealogies, folktales, and etiological myths.
#
#
# 442
# Early human settlements were typically based on low-lying hills or mounds.
#
#
#
# 555
# Bad Employers by Zeroing Out Subsidies

# %%
print(len(document))
print(len(labels))
# Out:
# 1992
# 1992

# %%
#stop words function
from spacy.lang.en import STOP_WORDS

stop_words_amazon = ''.join(STOP_WORDS)

stop_words_amazon_lemma = set(i.lemma_ for i in nlp(stop_words_amazon))

#lemmatizer function

def lemmatizer(text):
    return [word.lemma_ for word in nlp(text)]

# %%
#creating a pipeline

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split

tfidf = TfidfVectorizer(stop_words = stop_words_amazon_lemma, tokenizer = lemmatizer, ngram_range = (1,2))


X_train, X_test, y_train, y_test = train_test_split(document, labels, test_size=0.2)

pipe = Pipeline([
    ('vectorizer', tfidf),
    ('classifier', MultinomialNB())
])

pipe.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('vectorizer',
#                  TfidfVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.float64'>,
#                                  encoding='utf-8', input='content',
#                                  lowercase=True, max_df=1.0, max_features=None,
#                                  min_df=1, ngram_range=(1, 2), norm='l2',
#                                  preprocessor=None, smooth_idf=True,
#                                  stop_words={"indeedvariousmeanwhileonlynexteveryonefirstsoalonep...aroundthenceabovethusherselfbackthateverywheremightmorenotwouldsomewhereforty’dtheren‘tn’tamountamthemyour"},
#                                  strip_accents=None, sublinear_tf=False,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function lemmatizer at 0x000001FA4B743318>,
#                                  use_idf=True, vocabulary=None)),
#                 ('classifier',
#                  MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))],
#          verbose=False)

# %%
#printing the score on training set

print(f'The score for training set:{pipe.score(X_train, y_train)}')
# Out:
# The score for training set:0.7909604519774012

# %%
#making a grid

grid_parameters = {'vectorizer__ngram_range': [(1,1) , (1,2)],
                  'vectorizer__tokenizer': [None, lemmatizer]}

grid_search = GridSearchCV(pipe, grid_parameters, cv=5, verbose=1)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['delevensameitselffrom', 'dtheren', 'dyourselfbeside', 'indeedvariousmeanwhileonlynexteveryonefirstsoaloneperfifteenuntilandbecomingupontogetheriverywhencesidego', 'llhereuponanyonenevertowardseemsthroughitseverastherebyyoursnamelatterbecamemakethemselvesdosinceherereacrosscall', 'llthanwhilewellusagainstanywasduringthenwhetheroncenowheretheyanywayoutintopartorwhattwentyhewhereuponanotherhereinofmine', 'llwhithersuchbecomesdueifformerlypleasebymymuchhavewethroughoutupwhereinbeyondninebecausehaseverythingwithincaeachtenaenough', 'mhowallsixoursoff', 'mregardingothercannottheiranamongstwhosebefore', 'mthirdwithouttherefore', 'realsowhoeverwherewhomlastusedtowardsatothersmadetooourselves', 'reseemedityourselveshersviayounooneisleastneitherperhapsmoreoverhencemostlyhundredwhoshowaroundthenceabovethusherselfbackthateverywheremightmorenotwouldsomewhereforty', 'rethosehadwhereveronethoughsixtyforgivenoneanythingthereinbesideswholenorthereuponownhisalongwherebyotherwiseemptykeepelsedoingeighthimmayquitereallydoesintakeontoagainamongnow', 'sbefivenamelydonesomethingtopalwaysanyhowstillhoweveroveroftenwhybecomeshenothingabout', 'srathertwosometimes', 'sthreecouldsomeoneseemingfurtherfiftywhichn', 'tamountamthemyour', 'tfour', 'tn', 'vebothlessexceptmesaygetbottomwhereaswill', '', 'veshouldthruourbeingbeforehandtheseelsewhere'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['delevensameitselffrom', 'dtheren', 'dyourselfbeside', 'indeedvariousmeanwhileonlynexteveryonefirstsoaloneperfifteenuntilandbecomingupontogetheriverywhencesidego', 'llhereuponanyonenevertowardseemsthroughitseverastherebyyoursnamelatterbecamemakethemselvesdosinceherereacrosscall', 'llthanwhilewellusagainstanywasduringthenwhetheroncenowheretheyanywayoutintopartorwhattwentyhewhereuponanotherhereinofmine', 'llwhithersuchbecomesdueifformerlypleasebymymuchhavewethroughoutupwhereinbeyondninebecausehaseverythingwithincaeachtenaenough', 'mhowallsixoursoff', 'mregardingothercannottheiranamongstwhosebefore', 'mthirdwithouttherefore', 'realsowhoeverwherewhomlastusedtowardsatothersmadetooourselves', 'reseemedityourselveshersviayounooneisleastneitherperhapsmoreoverhencemostlyhundredwhoshowaroundthenceabovethusherselfbackthateverywheremightmorenotwouldsomewhereforty', 'rethosehadwhereveronethoughsixtyforgivenoneanythingthereinbesideswholenorthereuponownhisalongwherebyotherwiseemptykeepelsedoingeighthimmayquitereallydoesintakeontoagainamongnow', 'sbefivenamelydonesomethingtopalwaysanyhowstillhoweveroveroftenwhybecomeshenothingabout', 'srathertwosometimes', 'sthreecouldsomeoneseemingfurtherfiftywhichn', 'tamountamthemyour', 'tfour', 'tn', 'vebothlessexceptmesaygetbottomwhereaswill', '', 'veshouldthruourbeingbeforehandtheseelsewhere'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['delevensameitselffrom', 'dtheren', 'dyourselfbeside', 'indeedvariousmeanwhileonlynexteveryonefirstsoaloneperfifteenuntilandbecomingupontogetheriverywhencesidego', 'llhereuponanyonenevertowardseemsthroughitseverastherebyyoursnamelatterbecamemakethemselvesdosinceherereacrosscall', 'llthanwhilewellusagainstanywasduringthenwhetheroncenowheretheyanywayoutintopartorwhattwentyhewhereuponanotherhereinofmine', 'llwhithersuchbecomesdueifformerlypleasebymymuchhavewethroughoutupwhereinbeyondninebecausehaseverythingwithincaeachtenaenough', 'mhowallsixoursoff', 'mregardingothercannottheiranamongstwhosebefore', 'mthirdwithouttherefore', 'realsowhoeverwherewhomlastusedtowardsatothersmadetooourselves', 'reseemedityourselveshersviayounooneisleastneitherperhapsmoreoverhencemostlyhundredwhoshowaroundthenceabovethusherselfbackthateverywheremightmorenotwouldsomewhereforty', 'rethosehadwhereveronethoughsixtyforgivenoneanythingthereinbesideswholenorthereuponownhisalongwherebyotherwiseemptykeepelsedoingeighthimmayquitereallydoesintakeontoagainamongnow', 'sbefivenamelydonesomethingtopalwaysanyhowstillhoweveroveroftenwhybecomeshenothingabout', 'srathertwosometimes', 'sthreecouldsomeoneseemingfurtherfiftywhichn', 'tamountamthemyour', 'tfour', 'tn', 'vebothlessexceptmesaygetbottomwhereaswill', '', 'veshouldthruourbeingbeforehandtheseelsewhere'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['delevensameitselffrom', 'dtheren', 'dyourselfbeside', 'indeedvariousmeanwhileonlynexteveryonefirstsoaloneperfifteenuntilandbecomingupontogetheriverywhencesidego', 'llhereuponanyonenevertowardseemsthroughitseverastherebyyoursnamelatterbecamemakethemselvesdosinceherereacrosscall', 'llthanwhilewellusagainstanywasduringthenwhetheroncenowheretheyanywayoutintopartorwhattwentyhewhereuponanotherhereinofmine', 'llwhithersuchbecomesdueifformerlypleasebymymuchhavewethroughoutupwhereinbeyondninebecausehaseverythingwithincaeachtenaenough', 'mhowallsixoursoff', 'mregardingothercannottheiranamongstwhosebefore', 'mthirdwithouttherefore', 'realsowhoeverwherewhomlastusedtowardsatothersmadetooourselves', 'reseemedityourselveshersviayounooneisleastneitherperhapsmoreoverhencemostlyhundredwhoshowaroundthenceabovethusherselfbackthateverywheremightmorenotwouldsomewhereforty', 'rethosehadwhereveronethoughsixtyforgivenoneanythingthereinbesideswholenorthereuponownhisalongwherebyotherwiseemptykeepelsedoingeighthimmayquitereallydoesintakeontoagainamongnow', 'sbefivenamelydonesomethingtopalwaysanyhowstillhoweveroveroftenwhybecomeshenothingabout', 'srathertwosometimes', 'sthreecouldsomeoneseemingfurtherfiftywhichn', 'tamountamthemyour', 'tfour', 'tn', 'vebothlessexceptmesaygetbottomwhereaswill', '', 'veshouldthruourbeingbeforehandtheseelsewhere'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['delevensameitselffrom', 'dtheren', 'dyourselfbeside', 'indeedvariousmeanwhileonlynexteveryonefirstsoaloneperfifteenuntilandbecomingupontogetheriverywhencesidego', 'llhereuponanyonenevertowardseemsthroughitseverastherebyyoursnamelatterbecamemakethemselvesdosinceherereacrosscall', 'llthanwhilewellusagainstanywasduringthenwhetheroncenowheretheyanywayoutintopartorwhattwentyhewhereuponanotherhereinofmine', 'llwhithersuchbecomesdueifformerlypleasebymymuchhavewethroughoutupwhereinbeyondninebecausehaseverythingwithincaeachtenaenough', 'mhowallsixoursoff', 'mregardingothercannottheiranamongstwhosebefore', 'mthirdwithouttherefore', 'realsowhoeverwherewhomlastusedtowardsatothersmadetooourselves', 'reseemedityourselveshersviayounooneisleastneitherperhapsmoreoverhencemostlyhundredwhoshowaroundthenceabovethusherselfbackthateverywheremightmorenotwouldsomewhereforty', 'rethosehadwhereveronethoughsixtyforgivenoneanythingthereinbesideswholenorthereuponownhisalongwherebyotherwiseemptykeepelsedoingeighthimmayquitereallydoesintakeontoagainamongnow', 'sbefivenamelydonesomethingtopalwaysanyhowstillhoweveroveroftenwhybecomeshenothingabout', 'srathertwosometimes', 'sthreecouldsomeoneseemingfurtherfiftywhichn', 'tamountamthemyour', 'tfour', 'tn', 'vebothlessexceptmesaygetbottomwhereaswill', '', 'veshouldthruourbeingbeforehandtheseelsewhere'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['delevensameitselffrom', 'dtheren', 'dyourselfbeside', 'indeedvariousmeanwhileonlynexteveryonefirstsoaloneperfifteenuntilandbecomingupontogetheriverywhencesidego', 'llhereuponanyonenevertowardseemsthroughitseverastherebyyoursnamelatterbecamemakethemselvesdosinceherereacrosscall', 'llthanwhilewellusagainstanywasduringthenwhetheroncenowheretheyanywayoutintopartorwhattwentyhewhereuponanotherhereinofmine', 'llwhithersuchbecomesdueifformerlypleasebymymuchhavewethroughoutupwhereinbeyondninebecausehaseverythingwithincaeachtenaenough', 'mhowallsixoursoff', 'mregardingothercannottheiranamongstwhosebefore', 'mthirdwithouttherefore', 'realsowhoeverwherewhomlastusedtowardsatothersmadetooourselves', 'reseemedityourselveshersviayounooneisleastneitherperhapsmoreoverhencemostlyhundredwhoshowaroundthenceabovethusherselfbackthateverywheremightmorenotwouldsomewhereforty', 'rethosehadwhereveronethoughsixtyforgivenoneanythingthereinbesideswholenorthereuponownhisalongwherebyotherwiseemptykeepelsedoingeighthimmayquitereallydoesintakeontoagainamongnow', 'sbefivenamelydonesomethingtopalwaysanyhowstillhoweveroveroftenwhybecomeshenothingabout', 'srathertwosometimes', 'sthreecouldsomeoneseemingfurtherfiftywhichn', 'tamountamthemyour', 'tfour', 'tn', 'vebothlessexceptmesaygetbottomwhereaswill', '', 'veshouldthruourbeingbeforehandtheseelsewhere'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['delevensameitselffrom', 'dtheren', 'dyourselfbeside', 'indeedvariousmeanwhileonlynexteveryonefirstsoaloneperfifteenuntilandbecomingupontogetheriverywhencesidego', 'llhereuponanyonenevertowardseemsthroughitseverastherebyyoursnamelatterbecamemakethemselvesdosinceherereacrosscall', 'llthanwhilewellusagainstanywasduringthenwhetheroncenowheretheyanywayoutintopartorwhattwentyhewhereuponanotherhereinofmine', 'llwhithersuchbecomesdueifformerlypleasebymymuchhavewethroughoutupwhereinbeyondninebecausehaseverythingwithincaeachtenaenough', 'mhowallsixoursoff', 'mregardingothercannottheiranamongstwhosebefore', 'mthirdwithouttherefore', 'realsowhoeverwherewhomlastusedtowardsatothersmadetooourselves', 'reseemedityourselveshersviayounooneisleastneitherperhapsmoreoverhencemostlyhundredwhoshowaroundthenceabovethusherselfbackthateverywheremightmorenotwouldsomewhereforty', 'rethosehadwhereveronethoughsixtyforgivenoneanythingthereinbesideswholenorthereuponownhisalongwherebyotherwiseemptykeepelsedoingeighthimmayquitereallydoesintakeontoagainamongnow', 'sbefivenamelydonesomethingtopalwaysanyhowstillhoweveroveroftenwhybecomeshenothingabout', 'srathertwosometimes', 'sthreecouldsomeoneseemingfurtherfiftywhichn', 'tamountamthemyour', 'tfour', 'tn', 'vebothlessexceptmesaygetbottomwhereaswill', '', 'veshouldthruourbeingbeforehandtheseelsewhere'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['delevensameitselffrom', 'dtheren', 'dyourselfbeside', 'indeedvariousmeanwhileonlynexteveryonefirstsoaloneperfifteenuntilandbecomingupontogetheriverywhencesidego', 'llhereuponanyonenevertowardseemsthroughitseverastherebyyoursnamelatterbecamemakethemselvesdosinceherereacrosscall', 'llthanwhilewellusagainstanywasduringthenwhetheroncenowheretheyanywayoutintopartorwhattwentyhewhereuponanotherhereinofmine', 'llwhithersuchbecomesdueifformerlypleasebymymuchhavewethroughoutupwhereinbeyondninebecausehaseverythingwithincaeachtenaenough', 'mhowallsixoursoff', 'mregardingothercannottheiranamongstwhosebefore', 'mthirdwithouttherefore', 'realsowhoeverwherewhomlastusedtowardsatothersmadetooourselves', 'reseemedityourselveshersviayounooneisleastneitherperhapsmoreoverhencemostlyhundredwhoshowaroundthenceabovethusherselfbackthateverywheremightmorenotwouldsomewhereforty', 'rethosehadwhereveronethoughsixtyforgivenoneanythingthereinbesideswholenorthereuponownhisalongwherebyotherwiseemptykeepelsedoingeighthimmayquitereallydoesintakeontoagainamongnow', 'sbefivenamelydonesomethingtopalwaysanyhowstillhoweveroveroftenwhybecomeshenothingabout', 'srathertwosometimes', 'sthreecouldsomeoneseemingfurtherfiftywhichn', 'tamountamthemyour', 'tfour', 'tn', 'vebothlessexceptmesaygetbottomwhereaswill', '', 'veshouldthruourbeingbeforehandtheseelsewhere'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['delevensameitselffrom', 'dtheren', 'dyourselfbeside', 'indeedvariousmeanwhileonlynexteveryonefirstsoaloneperfifteenuntilandbecomingupontogetheriverywhencesidego', 'llhereuponanyonenevertowardseemsthroughitseverastherebyyoursnamelatterbecamemakethemselvesdosinceherereacrosscall', 'llthanwhilewellusagainstanywasduringthenwhetheroncenowheretheyanywayoutintopartorwhattwentyhewhereuponanotherhereinofmine', 'llwhithersuchbecomesdueifformerlypleasebymymuchhavewethroughoutupwhereinbeyondninebecausehaseverythingwithincaeachtenaenough', 'mhowallsixoursoff', 'mregardingothercannottheiranamongstwhosebefore', 'mthirdwithouttherefore', 'realsowhoeverwherewhomlastusedtowardsatothersmadetooourselves', 'reseemedityourselveshersviayounooneisleastneitherperhapsmoreoverhencemostlyhundredwhoshowaroundthenceabovethusherselfbackthateverywheremightmorenotwouldsomewhereforty', 'rethosehadwhereveronethoughsixtyforgivenoneanythingthereinbesideswholenorthereuponownhisalongwherebyotherwiseemptykeepelsedoingeighthimmayquitereallydoesintakeontoagainamongnow', 'sbefivenamelydonesomethingtopalwaysanyhowstillhoweveroveroftenwhybecomeshenothingabout', 'srathertwosometimes', 'sthreecouldsomeoneseemingfurtherfiftywhichn', 'tamountamthemyour', 'tfour', 'tn', 'vebothlessexceptmesaygetbottomwhereaswill', '', 'veshouldthruourbeingbeforehandtheseelsewhere'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['delevensameitselffrom', 'dtheren', 'dyourselfbeside', 'indeedvariousmeanwhileonlynexteveryonefirstsoaloneperfifteenuntilandbecomingupontogetheriverywhencesidego', 'llhereuponanyonenevertowardseemsthroughitseverastherebyyoursnamelatterbecamemakethemselvesdosinceherereacrosscall', 'llthanwhilewellusagainstanywasduringthenwhetheroncenowheretheyanywayoutintopartorwhattwentyhewhereuponanotherhereinofmine', 'llwhithersuchbecomesdueifformerlypleasebymymuchhavewethroughoutupwhereinbeyondninebecausehaseverythingwithincaeachtenaenough', 'mhowallsixoursoff', 'mregardingothercannottheiranamongstwhosebefore', 'mthirdwithouttherefore', 'realsowhoeverwherewhomlastusedtowardsatothersmadetooourselves', 'reseemedityourselveshersviayounooneisleastneitherperhapsmoreoverhencemostlyhundredwhoshowaroundthenceabovethusherselfbackthateverywheremightmorenotwouldsomewhereforty', 'rethosehadwhereveronethoughsixtyforgivenoneanythingthereinbesideswholenorthereuponownhisalongwherebyotherwiseemptykeepelsedoingeighthimmayquitereallydoesintakeontoagainamongnow', 'sbefivenamelydonesomethingtopalwaysanyhowstillhoweveroveroftenwhybecomeshenothingabout', 'srathertwosometimes', 'sthreecouldsomeoneseemingfurtherfiftywhichn', 'tamountamthemyour', 'tfour', 'tn', 'vebothlessexceptmesaygetbottomwhereaswill', '', 'veshouldthruourbeingbeforehandtheseelsewhere'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:  2.5min finished
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['delevensameitselffrom', 'dtheren', 'dyourselfbeside', 'indeedvariousmeanwhileonlynexteveryonefirstsoaloneperfifteenuntilandbecomingupontogetheriverywhencesidego', 'llhereuponanyonenevertowardseemsthroughitseverastherebyyoursnamelatterbecamemakethemselvesdosinceherereacrosscall', 'llthanwhilewellusagainstanywasduringthenwhetheroncenowheretheyanywayoutintopartorwhattwentyhewhereuponanotherhereinofmine', 'llwhithersuchbecomesdueifformerlypleasebymymuchhavewethroughoutupwhereinbeyondninebecausehaseverythingwithincaeachtenaenough', 'mhowallsixoursoff', 'mregardingothercannottheiranamongstwhosebefore', 'mthirdwithouttherefore', 'realsowhoeverwherewhomlastusedtowardsatothersmadetooourselves', 'reseemedityourselveshersviayounooneisleastneitherperhapsmoreoverhencemostlyhundredwhoshowaroundthenceabovethusherselfbackthateverywheremightmorenotwouldsomewhereforty', 'rethosehadwhereveronethoughsixtyforgivenoneanythingthereinbesideswholenorthereuponownhisalongwherebyotherwiseemptykeepelsedoingeighthimmayquitereallydoesintakeontoagainamongnow', 'sbefivenamelydonesomethingtopalwaysanyhowstillhoweveroveroftenwhybecomeshenothingabout', 'srathertwosometimes', 'sthreecouldsomeoneseemingfurtherfiftywhichn', 'tamountamthemyour', 'tfour', 'tn', 'vebothlessexceptmesaygetbottomwhereaswill', '', 'veshouldthruourbeingbeforehandtheseelsewhere'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('vectorizer',
#                                         TfidfVectorizer(analyzer='word',
#                                                         binary=False,
#                                                         decode_error='strict',
#                                                         dtype=<class 'numpy.float64'>,
#                                                         encoding='utf-8',
#                                                         input='content',
#                                                         lowercase=True,
#                                                         max_df=1.0,
#                                                         max_features=None,
#                                                         min_df=1,
#                                                         ngram_range=(1, 2),
#                                                         norm='l2',
#                                                         preprocessor=None,
#                                                         smooth_idf=True,
#                                                         stop...
#                                                         use_idf=True,
#                                                         vocabulary=None)),
#                                        ('classifier',
#                                         MultinomialNB(alpha=1.0,
#                                                       class_prior=None,
#                                                       fit_prior=True))],
#                                 verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'vectorizer__ngram_range': [(1, 1), (1, 2)],
#                          'vectorizer__tokenizer': [None,
#                                                    <function lemmatizer at 0x000001FA4B743318>]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=1)

# %%
#scores for the 
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'vectorizer__ngram_range': (1, 1), 'vectorizer__tokenizer': None}
# 0.7049591964846202

# %%
#scores for the pipeline model
print(pipe.score(X_test, y_test))
# Out:
# 0.6165413533834586

# %%
y_probability = pipe.predict_proba(X_test)
y_probability.shape
# Out:
# (399, 3)

# %%
grid_probabilty  = grid_search.predict_proba(X_test)
grid_probabilty
# Out:
# array([[0.09136707, 0.08133639, 0.82729653],
#        [0.6395364 , 0.09623164, 0.26423196],
#        [0.03872368, 0.0422475 , 0.91902883],
#        ...,
#        [0.27934714, 0.22033898, 0.50031387],
#        [0.36722953, 0.14537603, 0.48739443],
#        [0.36496164, 0.21334202, 0.42169634]])

# %%
#printing the results for the pipeline

prediction_indices = (y_probability[:,2] > 0.5).astype(int)


for i, index in enumerate(prediction_indices):
    print(X_test[i], "--> {} at {:g}%". format(y_test[index], 100*y_probability[i,index]))
# Out:
# Cicero is also generally disdainful of myth, but, like Varro, he is emphatic in his support for the state religion and its institutions. --> Amazon_Company at 3.35563%
# In an effort to boost employee morale, on November 2, 2015, Amazon announced that it would be extending six weeks of paid leave for new mothers and fathers. --> Greek Mythology at 47.9665%
# After the battle Scythians sent young men and told them to encamp near the Amazons and to do whatsoever they should do. --> Amazon_Company at 6.6803%
# = --> Amazon_Company at 16.9101%
# Employees are responsible for five basic tasks: unpacking and inspecting incoming goods; placing goods in storage and recording their location; picking goods from their computer recorded locations to make up an individual shipment; sorting and packing orders; and shipping. --> Amazon_Company at 9.52997%
# Wary of foreign exploitation of the nation's resources, Brazilian governments in the 1940s set out to develop the interior, away from the seaboard where foreigners owned large tracts of land. --> Amazon_Company at 20.5136%
# External links ==
#
#   --> Amazon_Company at 12.0104%
# = --> Amazon_Company at 16.9101%
# These Amazons started from Libya passed through Egypt and Syria, and stopped at the Caïcus in Aeolis, near which they founded several cities. --> Amazon_Company at 7.76397%
# At night the Greek fleet returned, and the Greeks from the horse opened the gates of Troy. --> Amazon_Company at 3.7284%
# s)—approximately 6,591 cubic kilometres per annum (1,581 cu mi/a), greater than the next seven largest independent rivers combined --> Greek Mythology at 12.4037%
# Instead, it returns a picture of the matching page, instructs the web browser to disable printing and puts limits on the number of pages in a book a single user can access. --> Amazon_Company at 8.70833%
# LIMC-France provides databases dedicated to Graeco-Roman mythology and its iconography.
#  --> Amazon_Company at 5.28509%
# = --> Amazon_Company at 16.9101%
# Herodotus and Strabo placed the Amazons on the banks of the Thermodon (today's Terme river) and Themiscyra (probably close to the modern city of Terme). --> Amazon_Company at 6.59672%
# The stories generally suggest that relationships between gods and mortals are something to avoid; even consenting relationships rarely have happy endings. --> Amazon_Company at 6.53887%
# Comments by Donald Trump and Bernie Sanders == --> Greek Mythology at 41.8703%
# It is the world's largest online marketplace, AI assistant provider, and cloud computing platform as measured by revenue and market capitalization. --> Greek Mythology at 47.3951%
# =
#  --> Amazon_Company at 4.71762%
# A few fragments of these works survive in quotations by Neoplatonist philosophers and recently unearthed papyrus scraps. --> Amazon_Company at 11.8617%
# The discovery of the Mycenaean civilization by the German amateur archaeologist Heinrich Schliemann in the nineteenth century, and the discovery of the Minoan civilization in Crete by the British archaeologist Sir Arthur Evans in the twentieth century, helped to explain many existing questions about Homer's epics and provided archaeological evidence for many of the mythological details about gods and heroes. --> Amazon_Company at 3.9793%
# =
#
#  --> Amazon_Company at 19.1564%
# Molpadia, an Amazon who killed Antiope.
#  --> Amazon_Company at 6.1348%
# Diodorus Siculus (Bibliotheca historica III, chapter 52) mentioned that besides Pontus Amazons existed much older race (at that time entirely disappeared) of Amazons from western Libya, and retells their mythological story which includes Atlantis and Greek mythology.
#
#  --> Amazon_Company at 2.14694%
# = --> Amazon_Company at 16.9101%
# = --> Amazon_Company at 16.9101%
# Also, on the island of Lemnos, there was another Myrina. --> Amazon_Company at 6.27091%
# Literature === --> Amazon_Company at 12.8169%
# In some cases, the first known representation of a myth in geometric art predates its first known representation in late archaic poetry, by several centuries. --> Amazon_Company at 7.08905%
# Johann Baptist von Spix and Carl Friedrich --> Amazon_Company at 21.5618%
# Reviewers must rate the product on a rating scale from one to five stars. --> Greek Mythology at 40.1781%
# Shelfari users built virtual bookshelves of the titles which they owned or had read and they could rate, review, tag and discuss their books. --> Amazon_Company at 6.81557%
# Hippo, an Amazon who took part in the introduction of religious rites in honor of the goddess Artemis. --> Amazon_Company at 3.25741%
# =
#  --> Amazon_Company at 4.71762%
# In Saturnalia reappear mythographical comments influenced by the Euhemerists, the Stoics and the Neoplatonists.
#
#
# == --> Amazon_Company at 10.3369%
# There are 75 fulfillment centers and 25 sortation centers with over 125,000 employees. --> Greek Mythology at 52.1926%
# Because of the backlash, the city of Orlando publicly stated it will no longer use the technology, but may revisit this decision at a later date.
#
#
#  --> Amazon_Company at 8.43523%
# The deities worshipped by them were Ares (who is consistently assigned to them as a god of war, and as a god of Thracian and generally northern origin) and Artemis, not the usual Greek goddess of that name, but an Asiatic deity in some respects her equivalent. --> Amazon_Company at 1.43205%
# Junglee started off as a virtual database that was used to extract information off the internet and deliver it to enterprise applications. --> Amazon_Company at 9.42349%
# The Amazons later moved to Themiscyra (speculated to be modern Terme, though no ruins exist) on the River Thermodon (the Terme river in northern Turkey).
#  --> Amazon_Company at 9.80265%
# = --> Amazon_Company at 16.9101%
# = --> Amazon_Company at 16.9101%
# Amazons were therefore depicted in the manner of Scythian or Sarmatian horsemen. --> Amazon_Company at 10.0509%
# = --> Amazon_Company at 16.9101%
# These were the early days of the world when the groups mingled more freely than they did later. --> Amazon_Company at 9.77214%
# "Amazon is known for its disruption of well-established industries through technological innovation and mass scale. --> Amazon_Company at 8.404%
# Smaller riverboats can reach 780 kilometres (480 mi) higher, as far as Achual Point. --> Greek Mythology at 10.2108%
# = --> Amazon_Company at 16.9101%
# From that point, Quebrada Carhuasanta emerges from Nevado Mismi, joins Quebrada Apacheta and soon forms Río Lloqueta which becomes Río Hornillos and eventually joins the Río Apurímac.
#  --> Amazon_Company at 31.0988%
# That same year, the company started Fulfillment by Amazon which managed the inventory of individuals and small companies selling their belongings through the company internet site. --> Greek Mythology at 69.6681%
# Strabo, giving credits to Metrodorus of Scepsis and Hypsicrates, mentions that at his time the Amazons were believed to live on the borders of the Gargareans. --> Amazon_Company at 6.36229%
# = --> Amazon_Company at 16.9101%
# =
#
#
#  --> Amazon_Company at 21.6423%
# = --> Amazon_Company at 16.9101%
# ComiXology == --> Amazon_Company at 17.9011%
# Amazon women mtDNA found in Mongolia
#  --> Amazon_Company at 13.5928%
# On the Trojan side:
#
#  --> Amazon_Company at 5.16711%
# = Greek and Roman conceptions of myth ==
#  --> Amazon_Company at 2.87912%
# = --> Amazon_Company at 16.9101%
# Fish === --> Amazon_Company at 23.6715%
# The Amazon is responsible for about 20% of the Earth's fresh water entering the ocean. --> Greek Mythology at 11.2764%
# Loading-bay doors were not opened to allow in fresh air because of concerns over theft. --> Amazon_Company at 15.3113%
# Trojan War and aftermath = --> Amazon_Company at 7.56471%
# In Chisholm, Hugh (ed.). --> Amazon_Company at 21.7769%
# Virgil's characterization of the Volscian warrior maiden Camilla in the Aeneid borrows heavily from the myth of the Amazons. --> Amazon_Company at 5.05561%
# = --> Amazon_Company at 16.9101%
# Any females that were born are retained by the Amazons themselves, but the males would be taken to the Gargareans to be brought up; and each Gargarean to whom a child is brought would adopt the child as his own, regarding the child as his son because of his uncertainty. --> Amazon_Company at 2.24065%
# In most countries where Amazon operates, a sales tax or value added tax is uniform throughout the country, and Amazon is obliged to collect it from all customers. --> Amazon_Company at 8.21944%
# After Alcippe's death, a group attack followed. --> Amazon_Company at 12.0016%
# = --> Amazon_Company at 16.9101%
# =
#
#  --> Amazon_Company at 19.1564%
# = --> Amazon_Company at 16.9101%
# = --> Amazon_Company at 16.9101%
# = --> Amazon_Company at 16.9101%
# His paintings “engendered all the aspirations of the Romantics: their desire to transcend the boundaries of the ego and of the known world; their interest in the occult in nature and in the soul; their search for a national identity, and the ensuing search for the mythic origins of the Germanic nation; finally, their wish to escape the harsh realities of the present through immersion in an idealized past.”
#
#
# == --> Amazon_Company at 2.76518%
# Scythians and Sarmatians == --> Amazon_Company at 13.6906%
# Amazons were said to have founded the cities and temples of Smyrna, Sinope, Cyme, Gryne, Ephesus, Pitania, Magnesia, Clete, Pygela, Latoreria and Amastris; according to legend, the Amazons also invented the cavalry. --> Amazon_Company at 3.66744%
# ==
#
# During what many archaeologists call the formative stage, Amazonian societies were deeply involved in the emergence of South America's highland agrarian systems. --> Amazon_Company at 30.3726%
# The Casiquiare is the largest river on earth that links two major river systems, a so-called bifurcation.
#
#
#  --> Amazon_Company at 35.2585%
# Using the same techniques, they calculated the length of the Nile as 6,853 kilometres (4,258 mi), which is longer than previous estimates but still shorter than the Amazon. --> Greek Mythology at 7.94986%
# Medieval and Renaissance literature ==
#
#  --> Amazon_Company at 11.2157%
# During the Hellenistic period, mythology took on the prestige of elite knowledge that marks its possessors as belonging to a certain class. --> Amazon_Company at 6.9389%
# The plume is about 400 kilometres (250 mi) long and between 100 and 200 kilometres (62 and 124 mi) wide. --> Greek Mythology at 7.94086%
# = --> Amazon_Company at 16.9101%
# Another Spanish explorer, Francisco de Orellana, was the first European to travel from the origins of the upstream river basins, situated in the Andes, to the mouth of the river. --> Amazon_Company at 47.1782%
# Some of the more famous heroes noted for their inclusion in the Trojan War were:
#  --> Amazon_Company at 4.2666%
# Amazon distributes downloads and streaming of video, music, and audiobooks through its Prime Video, Amazon Music, and Audible subsidiaries. --> Greek Mythology at 51.0226%
# Zeus then challenged Cronus to war for the kingship of the gods. --> Amazon_Company at 3.55972%
# = --> Amazon_Company at 16.9101%
# Preferring to die rather than give up his chastity, he threw himself into the river Amazonius, which was subsequently renamed Tanais.
#  --> Amazon_Company at 16.6993%
# Palaephatus, who was trying to rationalize the Greek myths in his On Unbelievable Tales --> Amazon_Company at 2.24625%
# mi).The quantity of water released by the Amazon to the Atlantic Ocean is enormous: up to 300,000 cubic metres per second (11,000,000 cu ft/s) in the rainy season, with an average of 209,000 cubic metres per second (7,400,000 cu ft/s) from 1973 to 1990. --> Greek Mythology at 9.58241%
# Stephanus of Byzantium, quoting Ephorus, mention that the tomb of the amazon Anaea (Ἀναία) was at the city of Anaea (Ἄναια), which also has this name after the amazon. --> Amazon_Company at 4.1832%
# Historians are uncertain whether the river he descended was the Amazon or the Orinoco River, which runs more or less parallel to the Amazon further north.
#  --> Amazon_Company at 25.3205%
# Heracles attained the highest social prestige through his appointment as official ancestor of the Dorian kings. --> Amazon_Company at 13.104%
# = --> Amazon_Company at 16.9101%
# The panel sent the case back to the lower court, to decide whether the leash was actually defective.
#
#
# == --> Amazon_Company at 18.694%
# When publishers asked Bezos why Amazon would publish negative reviews, he defended the practice by claiming that Amazon.com was "taking a different approach ... --> Amazon_Company at 9.29107%
# At an average discharge of about 209,000 cubic metres per second (7,400,000 cu ft/s; 209,000,000 L/s; 55,000,000 USgal/ --> Greek Mythology at 16.403%
# The company can also share the information with third parties. --> Greek Mythology at 56.4336%
# Amazon.com is primarily a retail site with a sales revenue model; Amazon takes a small percentage of the sale price of each item that is sold through its website while also allowing companies to advertise their products by paying to be listed as featured products. --> Greek Mythology at 69.7%
# Regardless of their underlying forms, the Ancient Greek gods have many fantastic abilities; most significantly, the gods are not affected by disease, and can be wounded only under highly unusual circumstances. --> Amazon_Company at 1.82678%
# The study by Carl Jung of the sexual archetypes has been studied extensively under the collective title of the Jungian archetypes. --> Amazon_Company at 8.75459%
# may I die, after doing vengeance upon the wrongdoer, that I may not stay here, jeered at beside the curved ships, a burden of the earth.
#  --> Amazon_Company at 4.83513%
# Among Classical Greeks, amazon was given a folk etymology as originating from a- --> Amazon_Company at 7.71145%
# He brings its residents in direct relation to the Amazons, namely based on its name (woman of the land Azzi = ' --> Amazon_Company at 5.09348%
# This follows the 2018 purchase of PillPack for under $1 billion, which has also been included into Amazon Care.
#
#
# === --> Amazon_Company at 10.1294%
# Modern legacy = --> Amazon_Company at 15.5303%
# concluded that the Amazon is actually longer than the Nile. --> Amazon_Company at 27.2564%
# Amazon filed communications license documents with the U.S. regulatory authorities the FCC in July 2019, which included information that the wholly owned Amazon subsidiary that intended to deploy the satellite constellation was Kuiper Systems LLC, based in Seattle, Washington.   --> Greek Mythology at 61.1452%
# =
#  --> Amazon_Company at 4.71762%
# Archaeology and mythography have revealed influence from Asia Minor and the Near East. --> Amazon_Company at 8.82502%
# Nonnus at Dionysiaca call the Amazons of Dionysus, Androphonus (Ἀνδροφόνους) ("men slaying").Herodotus stated that in the Scythian language they were called Oiorpata, oior meaning "man", and pata meaning "to slay".
#
#
# === --> Amazon_Company at 2.63402%
# so they were driven about by waves and winds and they were disembarked at the land of the Scythians. --> Amazon_Company at 7.43346%
# In mid-2018, investigations by journalists and media outlets such as The Guardian reported poor working conditions at Amazon's fulfillment centers. --> Greek Mythology at 52.0154%
# Other catfish 'walk' overland on their ventral fins, while the kumakuma (Brachyplatystoma filamentosum), aka piraiba or "goliath catfish", can reach 3.6 metres (12 ft) in length and 200 kilograms (440 lb) in weight. --> Amazon_Company at 19.4156%
# The company has also invested heavily on a massive amount of server capacity for its website, especially to handle the excessive traffic during the December Christmas holiday season. --> Greek Mythology at 47.3953%
# Amazon allows users to submit reviews to the web page of each product. --> Greek Mythology at 58.4082%
# = --> Amazon_Company at 16.9101%
# For instance, the cult of Sun was introduced in Rome after Aurelian's successful campaigns in Syria. --> Amazon_Company at 9.57217%
# Cybele is rooted in Anatolian culture while much of Aphrodite's iconography may spring from Semitic goddesses. --> Amazon_Company at 9.59794%
# They were brutal and aggressive, and their main concern in life was war. --> Amazon_Company at 8.93987%
# The most impressive temples tended to be dedicated to a limited number of gods, who were the focus of large pan-Hellenic cults. --> Amazon_Company at 5.82334%
# In the Archaic (c. 750 – c. 500 BC), Classical (c. 480–323 BC), and Hellenistic (323–146 BC) periods, Homeric and various other mythological scenes appear, supplementing the existing literary evidence.
#
#
# == --> Amazon_Company at 4.47845%
# Grigory Potemkin, a Russian military leader, statesman, nobleman and favourite of Catherine the Great created an Amazons Company in 1787. --> Amazon_Company at 8.00367%
# = --> Amazon_Company at 16.9101%
# "
#
# Later in the Renaissance, as Amazon myth evolved, artists started to depict warrior women in a new light. --> Amazon_Company at 3.81288%
# In works of art, battles between Amazons and Greeks are placed on the same level as – and often associated with – battles of Greeks and centaurs. --> Amazon_Company at 5.23696%
# The Nile is reported to be anywhere from 5,499 to 7,088 kilometres (3,417 to 4,404 mi). --> Greek Mythology at 12.7944%
# The president of Kuiper Systems is Rajeev Badyal, a former vice president of SpaceX's Starlink satellite internet constellation. --> Greek Mythology at 47.4893%
# A group of US Senators wrote an open letter to Bezos in March 2020, expressing concerns about worker safety. --> Greek Mythology at 50.7423%
# The challenge for Romans with a strong and apologetic sense of religious tradition was to defend that tradition while conceding that it was often a breeding-ground for superstition. --> Amazon_Company at 5.06978%
# During the time that the Scythians advanced into Asia and achieved near-hegemony in the Near East, there was a period of twenty-eight years when the men would have been away on campaigns for long periods. --> Amazon_Company at 3.89649%
# 6,400 km (4,000 mi) --> Greek Mythology at 11.5228%
# The tragic playwrights Aeschylus, Sophocles, and Euripides took most of their plots from myths of the age of heroes and the Trojan War. --> Amazon_Company at 1.50072%
# ==
#
#  --> Amazon_Company at 16.6089%
# Prose writers from the same periods who make reference to myths include Apuleius, Petronius, Lollianus, and Heliodorus. --> Amazon_Company at 4.138%
# Later, Diodorus maintains, they established Mytilene a little way beyond the Caïcus. --> Amazon_Company at 8.90615%
# = --> Amazon_Company at 16.9101%
# The success of the venture called attention to the opportunities for economic exploitation of the Amazon, and a second company soon opened commerce on the Madeira, Purús and Negro; a third established a line between Pará and Manaus; and a fourth found it profitable to navigate some of the smaller streams. --> Amazon_Company at 21.9085%
# Users could also create groups that other members could join, create discussions and talk about books, or other topics. --> Amazon_Company at 10.9271%
# Greek Myths on --> Amazon_Company at 3.5718%
# The second type (tales of punishment) involves the appropriation or invention of some important cultural artifact, as when Prometheus steals fire from the gods, when Tantalus steals nectar and ambrosia from Zeus' table and gives it to his own subjects—revealing to them the secrets of the gods, when Prometheus or Lycaon invents sacrifice, when Demeter teaches agriculture and the Mysteries to Triptolemus, or when Marsyas invents the aulos and enters into a musical contest with Apollo. --> Amazon_Company at 2.6332%
# der --> Amazon_Company at 18.2366%
# They were usually on horseback but sometimes on foot.
#  --> Amazon_Company at 10.6329%
# Historical background = --> Amazon_Company at 16.2799%
# = --> Amazon_Company at 16.9101%
# In Homer's works, such as the Iliad, the chief stories have already taken shape and substance, and individual themes were elaborated later, especially in Greek drama. --> Amazon_Company at 3.94036%
# House of Atreus and Theban Cycle == --> Amazon_Company at 12.4684%
# Although Apollonius wrote his poem in the 3rd century BC, the composition of the story of the Argonauts is earlier than Odyssey, which shows familiarity with the exploits of Jason (the wandering of Odysseus may have been partly founded on it). --> Amazon_Company at 2.79725%
# In the 2014 Hercules movie, a character named Atalanta is depicted as an Amazonian archer and a member of Hercules' traveling band of mercenaries.
#  --> Amazon_Company at 6.41429%
# Dealings with the Scythians == --> Amazon_Company at 8.78994%
# = --> Amazon_Company at 16.9101%
# Behind the myth of the house of Atreus (one of the two principal heroic dynasties with the house of Labdacus) lies the problem of the devolution of power and of the mode of accession to sovereignty. --> Amazon_Company at 5.97579%
# "The satellites will use an orbit with a height between 590 and 630 km (370 and 390 mi). --> Amazon_Company at 28.3695%
# In 2001, Amazon entered into a similar agreement with Borders Group, under which Amazon would comanage Borders.com as a co-branded service. --> Amazon_Company at 11.8137%
# =
#  --> Amazon_Company at 4.71762%
# = --> Amazon_Company at 16.9101%
# He arrived in Quito in 1637, and returned via the same route. --> Amazon_Company at 12.3306%
# In 1542, Francisco de Orellana reached the Amazon River (Amazonas in Spanish), naming it after a tribe of warlike women he claimed to have encountered and fought on the Nhamundá River, a tributary of the Amazon. --> Amazon_Company at 26.1206%
# He organised the "Companhia de Navegação e Comércio do Amazonas" in Rio de Janeiro in 1852; in the following year it commenced operations with four small steamers, the Monarca ('Monarch'), the Cametá, the Marajó and the Rio Negro. --> Amazon_Company at 24.9647%
# = --> Amazon_Company at 16.9101%
# This change includes birth parents and adoptive parents and can be applied in conjunction with existing maternity leave and medical leave for new mothers. --> Amazon_Company at 12.5423%
# these waters run side by side without mixing. --> Amazon_Company at 20.0898%
# The town of Manáos, now Manaus, at the mouth of the Rio Negro, had a population between 1,000 and 1,500. --> Greek Mythology at 10.182%
# = --> Amazon_Company at 16.9101%
# =
#  --> Amazon_Company at 4.71762%
# Philipp von Martius, 1817–1820
#  --> Amazon_Company at 17.4305%
# On 31 July 1867 the government of Brazil, constantly pressed by the maritime powers and by the countries encircling the upper Amazon basin, especially Peru, decreed the opening of the Amazon to all countries, but they limited this to certain defined points: Tabatinga – on the Amazon; Cametá – on the Tocantins; Santarém – on the Tapajós; Borba – on the Madeira, and Manaus – on the Rio Negro. --> Amazon_Company at 31.3922%
# Also, he mentions that on an island, the Queens of the Amazons, Otrere (Ὀτρηρή) and Antiope (Ἀντιόπη), built a marble temple to Ares. --> Amazon_Company at 3.07451%
# = --> Amazon_Company at 16.9101%
# = --> Amazon_Company at 16.9101%
# Lab126 = --> Amazon_Company at 16.9101%
# = --> Amazon_Company at 16.9101%
# = --> Amazon_Company at 16.9101%
# There are approximately 30 to 60 species of piranha. --> Greek Mythology at 16.5743%
# = Watershed ==
#
#  --> Amazon_Company at 16.2843%
# Companies like Groupon, eBay and Taap.it countered Amazon's promotion by offering $10 off from their products. --> Greek Mythology at 60.7838%
# Alexandrian poets at first, then more generally literary mythographers in the early Roman Empire, often re-adapted stories of Greek mythological characters in this fashion.
#  --> Amazon_Company at 3.45421%
# = --> Amazon_Company at 16.9101%
# The old myths were kept alive in local cults; they continued to influence poetry and to form the main subject of painting and sculpture. --> Amazon_Company at 8.78928%
# The New York state attorney general, Letitia James, is considering legal retaliation to the firing. --> Amazon_Company at 15.1735%
# He later used them in his campaign against the Bactria. --> Amazon_Company at 6.01173%
# In fact, true cinnamon (Cinnamomum verum) is not native to South America. --> Amazon_Company at 25.894%
# Amazon funds both climate denial groups including the Competitive Enterprise Institute and politicians denying climate change including Jim Inhofe. --> Greek Mythology at 36.6747%
# A variety of methods were used to compare the lengths of the Mantaro river vs. the Apurímac river from their most distant source points to their confluence, showing the longer length of the Mantaro. --> Greek Mythology at 7.95897%
# Greeks also used other descriptive phrases for them. --> Amazon_Company at 5.42754%
# Ajax (there were two Ajaxes)
#  --> Amazon_Company at 7.65709%
# Fauna == --> Greek Mythology at 25.3433%
# a Panorama documentary highlighted the amount of data collected by the company and the move into surveillance causing concerns of politicians and regulators in the US and Europe.
#
#
#  --> Greek Mythology at 39.0823%
# = --> Amazon_Company at 16.9101%
# Audible sells digital audiobooks, radio and TV programs and audio versions of magazines and newspapers. --> Greek Mythology at 45.4566%
# The UK government awarded Amazon a contract that gives the company free access to healthcare information collected by the UK's National Health Service. --> Greek Mythology at 65.7604%
# Subsidiaries ==
#
#  --> Amazon_Company at 16.4013%
# Pindar, Apollonius and the Bibliotheca endeavor to give full lists of the Argonauts. --> Amazon_Company at 9.2044%
# According to a commentary, it was purported to mean "drunkard" in the local language.
#  --> Amazon_Company at 4.03756%
# = --> Amazon_Company at 16.9101%
# An Amazon warehouse protest on March 30, 2020 in Staten Island led to its organizer, Christian Smalls, being fired by the company; they defended the action by saying that he was supposed to be in self-isolation at the time and leading the protest put its other workers at risk. --> Amazon_Company at 6.35627%
# Kuiper will work in concert with Amazon's previously announced large network of 12 satellite ground station facilities (the "AWS Ground Station unit") --> Amazon_Company at 15.035%
# Latoreia, who had a small village near Ephesus named after her.
# Lysippe, mother of Tanais by Berossos. --> Amazon_Company at 4.73445%
# Smaller ocean vessels of 3,000 or 9,000 tonnes (3,000 or 8,900 long tons; 3,300 or 9,900 short tons) and 5.5 metres (18 ft) draft can reach as far as Iquitos, Peru, 3,600 kilometres (2,200 mi) from the sea. --> Greek Mythology at 6.93268%
# Hippolyta complied and Heracles let her go. --> Amazon_Company at 9.6132%
# Plato created his own allegorical myths (such as the vision of Er in the Republic), attacked the traditional tales of the gods' tricks, thefts and adulteries as immoral, and objected to their central role in literature. --> Amazon_Company at 1.89102%
# John Tzetzes in Posthomerica enumerates the Amazons who fell at Troy: Hippothoe, Antianeira, Toxophone, Toxoanassa, Gortyessa, Iodoce, Pharetre, Andro, Ioxeia, Oïstrophe, Androdaïxa, Aspidocharme, Enchesimargos, Cnemis, Thorece, Chalcaor, Eurylophe, Hecate, Anchimache, Andromache the queen. --> Amazon_Company at 6.2902%
# She fought Achilles and died after he gravely wounded her.
#  --> Amazon_Company at 4.83077%
# " Amazon's shares fell by 6 percent as a result of Trump's comments. --> Amazon_Company at 14.2217%
# Shahbazi, A.S. (1989). --> Amazon_Company at 16.1%
# There are also possible parallels between the earliest divine generations (Chaos and its children) and Tiamat in the Enuma Elish. --> Amazon_Company at 3.93209%
# The earlier inhabitants of the Balkan Peninsula were an agricultural people who, using Animism, assigned a spirit to every aspect of nature. --> Amazon_Company at 11.671%
# = --> Amazon_Company at 16.9101%
# The Amazon sales rank (ASR) provides an indication of the popularity of a product sold on any Amazon locale. --> Amazon_Company at 9.93889%
# The epic and genealogical poetry created cycles of stories clustered around particular heroes or events and established the family relationships between the heroes of different stories; they thus arranged the stories in sequence. --> Amazon_Company at 3.64141%
# as for those who do proceed by proving their assertions, we must cross-examine them". --> Amazon_Company at 4.67387%
# However, Amazon has now begun to release point of sale data via the Nielsen BookScan service to verified authors. --> Greek Mythology at 43.5535%
# = --> Amazon_Company at 16.9101%
# Mouth == --> Greek Mythology at 23.5403%
# In March 1500, Spanish conquistador Vicente Yáñez Pinzón was the first documented European to sail up the Amazon River. --> Greek Mythology at 10.4492%
# In addition to the thousands of species of fish, the river supports crabs, algae, and turtles.
#
#
#  --> Amazon_Company at 31.685%
# The Legend of the Hidden City, Princess Kama's bodyguards are Amazons led by Commander Nefret.
#  --> Amazon_Company at 8.9879%
# In particular, products that experience large jumps (up or down) in their sales ranks may be included within Amazon's lists of "movers and shakers"; such a listing provides additional exposure that might lead to an increase in sales. --> Amazon_Company at 7.38233%
# Adrienne Mayor suggests that the false etymology led to the myth.
#
#
#  --> Amazon_Company at 3.87786%
# In February 2019, Étienne Tête filed a request on behalf of a second regional community action group asking the administrative court to decide whether the platform served a sufficiently important public interest to justify its environmental impact. --> Greek Mythology at 55.6568%
# After the rise of the hero cult, gods and heroes constitute the sacral sphere and are invoked together in oaths and prayers which are addressed to them. --> Amazon_Company at 4.20707%
# =
#
#  --> Amazon_Company at 19.1564%
# In Ukraine Katerina Tarnovska leads a group called the Asgarda which claims to be a new tribe of Amazons. --> Amazon_Company at 7.38579%
# On the south bank, above the Xingu, a line of low bluffs bordering the floodplain extends nearly to Santarém in a series of gentle curves before they bend to the southwest, and, abutting upon the lower Tapajós, merge into the bluffs which form the terrace margin of the Tapajós river valley.
#
#
#  --> Amazon_Company at 26.6159%
# Claude Lévi-Strauss and other structuralists have compared the formal relations and patterns in myths throughout the world. --> Amazon_Company at 9.70999%
# = --> Amazon_Company at 16.9101%
# She notes that she has not found any Elizabethans comparing the queen directly to an Amazon, and suggests that they might have hesitated to do so because of the association of Amazons with enfranchisement of women, which was considered contemptible."Peter --> Amazon_Company at 3.89517%
# = --> Amazon_Company at 16.9101%
# =
#
#
#  --> Amazon_Company at 21.6423%
# Tylor's procedure of drawing together material culture, ritual and myth of widely separated cultures influenced both Carl Jung and Joseph Campbell. --> Amazon_Company at 6.30227%
# A tribe of Amazons appeared in the Tarzan, Lord of the Jungle episode "Tarzan and the Amazon Princess."
#  --> Amazon_Company at 4.21327%
# that is, close-fitting trousers and a high cap called the kidaris. --> Amazon_Company at 12.9909%
# This, although the government believed it could sustain millions, instead could sustain very few. --> Amazon_Company at 21.719%
# For example, philologist Georges Dumézil draws a comparison between the Greek Uranus and the Sanskrit Varuna, although there is no hint that he believes them to be originally connected. --> Amazon_Company at 3.48913%
# Previously existing myths, such as those of Achilles and Patroclus, also then were cast in a pederastic light. --> Amazon_Company at 4.83381%
# Polyaenus writes that after Dionysus had subdued the Indians, he formed an alliance with them and the Amazons, and took them into his service. --> Amazon_Company at 4.21051%
# There are many factors that can affect these measurements, such as the position of the geographical source and the mouth, the scale of measurement, and the length measuring techniques (for details see also List of rivers by length).A study by Brazilian scientists --> Amazon_Company at 22.0912%
# In the animated series Huntik: Secrets & Seekers, Queen Hippolyta and the Amazons appear in the episode Ladies' Choice.
#  --> Amazon_Company at 3.18084%
# =
#  --> Amazon_Company at 4.71762%
# Other related cinnamon-containing plants (of the family Lauraceae) are fairly common in that part of the Amazon and Pizarro probably saw some of these. --> Amazon_Company at 11.3747%
# we want to make every book available—the good, the bad and the ugly ... to let truth loose". --> Amazon_Company at 7.94397%
# Old Norse Tyr". --> Amazon_Company at 8.27074%
# During glacial periods, sea levels dropped and the great Amazon lake rapidly drained and became a river, which would eventually become the world's second largest, draining the most extensive area of rainforest on the planet. --> Amazon_Company at 23.6357%
# Cambridge University Press. --> Amazon_Company at 22.8509%
# Ammianus places them east of Tanais, as neighbouring the Alans. --> Amazon_Company at 11.24%
# Diodorus Siculus, giving the account of Dionysius of Mitylene, who, on his part, drew on Thymoetas, states that before the Amazons of the Thermodon there were, much earlier in time, the Amazons of Libya. --> Amazon_Company at 2.99778%
# Franchises involving Tarzan have featured Amazon tribes:
#  --> Amazon_Company at 9.53368%
# The drainage area of the Amazon basin above Óbidos city is about 5,000,000 square kilometres (1,900,000 sq mi), and, below, only about 1,000,000 square kilometres (390,000 sq mi) (around 20%), exclusive of the 1,400,000 square kilometres (540,000 sq mi) of the Tocantins basin. --> Greek Mythology at 3.40306%
# = --> Amazon_Company at 16.9101%
# = --> Amazon_Company at 16.9101%
# = --> Amazon_Company at 16.9101%
# They used myth to explain natural phenomena, cultural variations, traditional enmities and friendships. --> Amazon_Company at 9.66653%
# These pre-Columbian settlements created highly developed civilizations. --> Amazon_Company at 26.3925%
# Multi-level sales strategy = --> Greek Mythology at 48.2569%
# = --> Amazon_Company at 16.9101%
# Most gods were associated with specific aspects of life. --> Amazon_Company at 13.0567%
# They were followed by the one-eyed Cyclopes and the Hecatonchires or Hundred-Handed Ones, who were both thrown into Tartarus by Uranus. --> Amazon_Company at 5.81627%
# Amazon will also lobby to make $15 an hour the federal minimum wage. --> Greek Mythology at 60.405%
# In 2015, Amazon surpassed Walmart as the most valuable retailer in the United States by market capitalization. --> Greek Mythology at 58.8654%
# The antiquarian Varro, who regarded religion as a human institution with great importance for the preservation of good in society, devoted rigorous study to the origins of religious cults. --> Amazon_Company at 3.54165%
# = --> Amazon_Company at 16.9101%
# = --> Amazon_Company at 16.9101%
# The definition of where exactly the mouth of the Amazon is located, and how wide it is, is a matter of dispute, because of the area's peculiar geography. --> Amazon_Company at 15.0702%
# During this time the women would not only have had to defend themselves, but to reproduce, and this could well be the origin of the idea that Amazons mated once a year with their neighbours, if Herodotus actually based his accounts on fact. --> Amazon_Company at 2.55429%
# The comic playwright Aristophanes also used myths, in The Birds and The Frogs. --> Amazon_Company at 5.22337%
# = --> Amazon_Company at 16.9101%
# One day a Scythian and an Amazon came close. --> Amazon_Company at 10.1025%
# = --> Amazon_Company at 16.9101%
# Derrick Palmer, another worker at the Staten Island facility, told The Verge that Amazon quickly communicates through text and email when they need the staff to complete mandatory overtime, but have not been using this to tell people when a colleague has contracted the disease, instead waiting days and sending managers to speak to employees in person. --> Amazon_Company at 7.01844%
# = --> Amazon_Company at 16.9101%
# = --> Amazon_Company at 16.9101%
# Diodorus mentions that the Amazons traveled from Libya under Queen Myrina. --> Amazon_Company at 5.72129%
# Jordanes also mentions that they fought with Hercules, and in the Trojan War, and that a smaller contingent of them endured in the Caucasus Mountains until the time of Alexander. --> Amazon_Company at 1.85088%
# = --> Amazon_Company at 16.9101%
# Ring ===
#
#  --> Amazon_Company at 16.1425%
# Through the medium of Latin and the works of Ovid, Greek myth influenced medieval and Renaissance poets such as Petrarch, Boccaccio and Dante in Italy.
#
#  --> Amazon_Company at 3.17992%
# Amazon acquired Junglee in 1998, and the website Junglee.com was launched in India in February 2012 as a comparison-shopping website. --> Greek Mythology at 51.1993%
# = --> Amazon_Company at 16.9101%
# Lab126, developers of integrated consumer electronics such as the Kindle, became a subsidiary in 2004.
#
#
#  --> Amazon_Company at 11.9523%
# In addition, the city Anaea in Caria was named after the Amazon.
#  --> Amazon_Company at 5.61584%
# "Amazon should pay these costs (plus) and not have them bourne [sic] by the American Taxpayer. --> Amazon_Company at 8.82622%
# It was also extremely popular, forming a cycle to which a number of local legends became attached. --> Amazon_Company at 7.41999%
# However, analyst Tom Forte pointed to the fact that Amazon's payments to the USPS are not made public and that their contract has a reputation for being "a sweetheart --> Amazon_Company at 8.90082%
# In 2004, Toys "R" Us sued Amazon, claiming that because of a perceived lack of variety in Toys "R" --> Greek Mythology at 38.2343%
# Gnaeus Pompeius Trogus pays particularly detailed attention to the Amazons. --> Amazon_Company at 17.3317%
# After the rise of philosophy, history, prose and rationalism in the late 5th century BC, the fate of myth became uncertain, and mythological genealogies gave place to a conception of history which tried to exclude the supernatural (such as the Thucydidean history). --> Amazon_Company at 4.6044%
# At Patmos there was a place called Amazonium. --> Amazon_Company at 8.43423%
# From the town of Canaria at the great bend of the Amazon to the Negro, vast areas of land are submerged at high water, above which only the upper part of the trees of the sombre forests appear. --> Amazon_Company at 29.9344%
# The most important microbes in the Amazon River are Actinobacteria, Alphaproteobacteria, Betaproteobacteria, Gammaproteobacteria and Crenarchaeota.
#
#
#  --> Amazon_Company at 27.466%
# = --> Amazon_Company at 16.9101%
# In addition to Indo-European and Near Eastern origins, some scholars have speculated on the debts of Greek mythology to the indigenous pre-Greek societies: Crete, Mycenae, Pylos, Thebes and Orchomenus. --> Amazon_Company at 3.42806%
# On this desert island there were ravening birds, which in countless numbers haunt it. --> Amazon_Company at 10.0079%
# Its population is limited to freshwater habitats, and, unlike other manatees, it does not venture into salt water. --> Amazon_Company at 19.419%
# Protected areas = --> Greek Mythology at 26.5632%
# Titans were to be born. --> Amazon_Company at 10.2735%
# The reason for the protests is the company policy to "run normal shifts" despite many positive cases of the virus. --> Greek Mythology at 39.7629%
# He also pointed to the fact that Amazon had paid no federal income tax in the previous year. --> Amazon_Company at 11.9895%
# Other names == --> Amazon_Company at 15.1164%
# The Kuiper System includes high-performance satellites, terrestrial gateways, internetworking technologies, and a range of customer terminals. --> Greek Mythology at 38.4482%
# Us would be the exclusive supplier of toys and baby products on the service, and the chain's website would redirect to Amazon's Toys & Games category. --> Greek Mythology at 60.1185%
# Amazon is also building out its logistics in trucking and air freight to potentially compete with UPS and FedEx.
#
#
# === --> Amazon_Company at 8.60546%
# = --> Amazon_Company at 16.9101%
# Because of the terra preta, indigenous communities were able to make land fertile and thus sustainable for the large-scale agriculture needed to support their large populations and complex social structures. --> Greek Mythology at 19.1566%
# =
#  --> Amazon_Company at 4.71762%
# Hamza River
#  --> Greek Mythology at 22.0597%
# = --> Amazon_Company at 16.9101%
# Melanippe, sister of Hippolyta. --> Amazon_Company at 13.7392%
# = --> Amazon_Company at 16.9101%
# = --> Amazon_Company at 16.9101%
# = --> Amazon_Company at 16.9101%
# *kar- "make" (from which Sanskrit karma is also derived).
#
#
# == --> Amazon_Company at 4.80879%
# Wounded Amazon
# Herodotus on the Amazons
#  --> Amazon_Company at 10.5277%
# Seattle head tax and houselessness services = --> Greek Mythology at 57.6567%
# The word Amazon itself may be derived from the Iranian compound *ha-maz-an- "(one) fighting together" or ethnonym * --> Amazon_Company at 5.46025%
# = --> Amazon_Company at 16.9101%
# pp. --> Amazon_Company at 13.3832%
# After Penthesilea's death she, in accord with the former's will, sailed off and eventually landed in Italy, founding the city of Clete.
#  --> Amazon_Company at 4.22993%
# = --> Amazon_Company at 16.9101%
# In another myth Dionysus united with the Amazons to fight against Cronus and the Titans. --> Amazon_Company at 3.35746%
# Moreover, said Herodotus, "No girl shall wed till she has killed a man in battle". --> Amazon_Company at 2.62321%
# announced in November 2018. --> Greek Mythology at 59.6519%
# = --> Amazon_Company at 16.9101%
# Finally there are two pseudo-chronicles written in Latin that passed under the names of Dictys Cretensis and Dares Phrygius. --> Amazon_Company at 6.84549%
# The company eventually installed air conditioning at the warehouse. --> Greek Mythology at 51.7907%
# When Hermes invents the lyre in the Homeric Hymn to Hermes, the first thing he does is sing about the birth of the gods. --> Amazon_Company at 4.90239%
# = --> Amazon_Company at 16.9101%
# Primary sources (Greek and Roman) == --> Amazon_Company at 7.44705%
# In psychology == --> Amazon_Company at 12.4583%
# Amazon.com originally collected sales tax only from five states as of 2011, but as of April 2017, Amazon collects sales taxes from customers in all 45 states that have a state sales tax and in Washington, D.C.
#
#
# === --> Greek Mythology at 66.0389%
# =
#  --> Amazon_Company at 4.71762%
# Survey of mythic history ==
#
#  --> Amazon_Company at 20.671%
# (It is not known whether the Seven Against Thebes figured in early epic.) --> Amazon_Company at 9.03941%
# In 1871 Edward Burnett Tylor published his Primitive Culture, in which he applied the comparative method and tried to explain the origin and evolution of religion. --> Amazon_Company at 6.97632%
# ParisOn --> Amazon_Company at 22.0339%
# =
#
#  --> Amazon_Company at 19.1564%
# The origin of the word is uncertain. --> Amazon_Company at 10.712%
# According to J. Viirtheim (De Ajacis origine, 1907), the Amazons were of Greek origin [...] --> Amazon_Company at 4.67185%
# There are no bridges across the entire width of the river. --> Amazon_Company at 40.4903%
# Research on the influence of the Amazon River on the Atlantic Ocean at the University of Southern California
#  Geographic data related to Amazon River at OpenStreetMap --> Greek Mythology at 10.9628%
# = --> Amazon_Company at 16.9101%
# The dolphins use echolocation to navigate and hunt in the river's tricky depths. --> Greek Mythology at 14.3941%
# Kuiper Systems = --> Greek Mythology at 37.0389%
# External links ==
#
#  --> Amazon_Company at 12.5147%
# A tribe of Amazons were in the film Tarzan and the Amazons.
#  --> Amazon_Company at 5.40892%
# The account of Justinus was influential, and was used as a source by Orosius who continued to be read during the European Middle Ages. --> Amazon_Company at 4.06804%
# = --> Amazon_Company at 16.9101%
# Burkert notes that "the roster of heroes, again in contrast to the gods, is never given fixed and final form. --> Amazon_Company at 3.72946%
# Yet another different set of names is found in Valerius Flaccus' Argonautica: he mentions Euryale, Harpe, Lyce, Menippe and Thoe. --> Amazon_Company at 6.41158%
# In his later years, however, towards the end of the Trojan War, his old opponents took his side against the Greeks under their queen Penthesilea "of Thracian birth", who was slain by Achilles. --> Amazon_Company at 1.01736%
# From that union were born first the Titans—six males: Coeus, Crius, Cronus, Hyperion, Iapetus, and Oceanus; and six females: Mnemosyne, Phoebe, Rhea, Theia, Themis, and Tethys. --> Amazon_Company at 6.19909%
# As of 2015, the service had over 1.5 million broadcasters and 100 million monthly viewers.
#
#
#  --> Greek Mythology at 56.1276%
# Amazon employs a multi-level e-commerce strategy. --> Greek Mythology at 47.5289%
# Heracles and the Heracleidae == --> Amazon_Company at 12.8363%
# =
#
#
#  --> Amazon_Company at 21.6423%
# = --> Amazon_Company at 16.9101%
# While his tragic end provided much material for tragedy—Heracles is regarded by Thalia Papadopoulou as "a play of great significance in examination of other Euripidean dramas". --> Amazon_Company at 4.19216%
# Early scientific, zoological and botanical exploration of the Amazon River and basin took place from the 18th century through the first half of the 19th century.
#
#  --> Amazon_Company at 23.1594%
# The service was first established as a spin-off of a general-interest streaming service known as Justin.tv. --> Amazon_Company at 9.67195%
# Since its founding, the company has attracted criticism and controversy for its actions, including: supplying law enforcement with facial recognition surveillance tools; forming cloud computing partnerships with the CIA; leading customers away from bookshops; adversely impacting the environment; placing a low priority on warehouse conditions for workers; actively opposing unionization efforts; remotely deleting content purchased by Amazon Kindle users; taking public subsidies; seeking to patent its 1-Click technology; engaging in anti-competitive actions and price discrimination; and reclassifying LGBT books as adult content. --> Greek Mythology at 54.5785%
# Further reading ==
#
#
# == --> Amazon_Company at 17.8421%
# Amazons also appear in the Rococo period in another painting titled Battle of the Amazons by Johann Georg Platzer. --> Amazon_Company at 6.83132%
# During the outbreak of the Coronavirus pandemic (COVID-19) there have been protests by the Amazon workers at warehouses in the US, France, and Italy. --> Amazon_Company at 8.93133%
# For competitive reasons, Amazon does not release actual sales figures to the public. --> Greek Mythology at 40.1037%
# It is the richest tropical forest in the world in terms of biodiversity. --> Amazon_Company at 23.2784%
# Despite their traditional name, the "Homeric Hymns" have no direct connection with Homer. --> Amazon_Company at 6.44933%
# In other cases, close parallels in character and function suggest a common heritage, yet lack of linguistic evidence makes it difficult to prove, as in the case of the Greek Moirai and the Norns of Norse mythology. --> Amazon_Company at 5.84796%
# = --> Amazon_Company at 16.9101%
# Amazon announced it would buy Eero in 2019.
#
#
#  --> Greek Mythology at 60.033%
# Livy, too, is skeptical about the mythological tradition and claims that he does not intend to pass judgement on such legends (fabulae). --> Amazon_Company at 4.51335%
# Other members of this earliest generation of heroes such as Perseus, Deucalion, Theseus and Bellerophon, have many traits in common with Heracles. --> Amazon_Company at 2.94774%
# Another Amazonian freshwater fish is the arowana (or aruanã in Portuguese), such as the silver arowana (Osteoglossum bicirrhosum), which is a predator and very similar to the arapaima, but only reaches a length of 120 centimetres (47 in). --> Amazon_Company at 13.8528%
# While debate as to whether the Amazon or the Nile is the world's longest river has gone on for many years, the historic consensus of geographic authorities has been to regard the Amazon as the second longest river in the world, with the Nile being the longest. --> Amazon_Company at 24.3646%
# Geometric designs on pottery of the eighth century BC depict scenes from the Trojan cycle, as well as the adventures of Heracles. --> Amazon_Company at 3.20684%
# The company was later awarded $51 million in damages. --> Greek Mythology at 65.6973%
# Since 2019, the company has instead offered customer an "Amazon Day" option, where all orders are delivered on the same day, emphasizing customer convenience, and it occasionally offers Prime customers credits in return for selecting slower and less expensive shipping options.
#
#
#  --> Greek Mythology at 49.1978%
# In 2017, Amazon acquired Whole Foods Market for US$13.4 billion, which vastly increased Amazon's presence as a brick-and-mortar retailer. --> Greek Mythology at 72.3617%
# =
#
#
#  --> Amazon_Company at 21.6423%
# Other names of Amazons from various sources include:
#
# Aegea, queen of the Amazons who was thought by some to have been the eponym of the Aegean Sea.
#  --> Amazon_Company at 1.6717%
# If upheld, the decision would expose Amazon and similar platform businesses to strict liability lawsuits for defective products, which represents a major change in the law. --> Amazon_Company at 11.6047%
# Each god descends from his or her own genealogy, pursues differing interests, has a certain area of expertise, and is governed by a unique personality; however, these descriptions arise from a multiplicity of archaic local variants, which do not always agree with one another. --> Amazon_Company at 4.41584%
# Sending a hero to his presumed death is also a recurrent theme of this early heroic tradition, used in the cases of Perseus and Bellerophon.
#
#
#  --> Amazon_Company at 3.47593%
# If distribution centers are not safe for workers right now, they should be closed immediately." --> Amazon_Company at 7.69586%
# In 2006, a court ruled in favor of Toys "R" Us, giving it the right to unwind its agreement with Amazon and establish its own independent e-commerce website. --> Amazon_Company at 5.48491%
# Racine in France and Goethe in Germany revived Greek drama, reworking the ancient myths. --> Amazon_Company at 5.3653%
# = --> Amazon_Company at 16.9101%
# Paul Rubens and Jan Brueghel depicted the Battle of the Amazons around 1598, showing many attributes of Renaissance-styled paintings. --> Amazon_Company at 7.67334%
# =
#  --> Amazon_Company at 4.71762%
# In the Works and Days, Hesiod makes use of a scheme of Four Ages of Man (or Races): --> Amazon_Company at 3.66662%
# One of them seduces Dean Winchester and has a child, who quickly ages to a teenager and attempts to kill him, only to be shot by Sam Winchester.
#  --> Amazon_Company at 2.72388%
# The gods of Greek mythology are described as having essentially corporeal but ideal bodies. --> Amazon_Company at 2.21154%
# Two other important non-poetical sources are the Fabulae and Astronomica of the Roman writer styled as Pseudo-Hyginus, the Imagines of Philostratus the Elder and Philostratus the Younger, and the Descriptions of Callistratus.
#  --> Amazon_Company at 4.46871%
# But the Amazons knew nothing about ships --> Amazon_Company at 16.7235%
# Third-party sellers == --> Greek Mythology at 58.7312%
# Facial recognition technology and law enforcement = --> Greek Mythology at 39.0554%
# =
#
#
#  --> Amazon_Company at 21.6423%
# It is primarily known for its WiFi powered smart doorbells, but manufactures other devices such as security cameras. --> Amazon_Company at 7.52148%
# Information on the Amazon from Extreme Science
#  --> Amazon_Company at 15.1533%

# %%
#printing the results for GridSearch

prediction_indices = (grid_probabilty[:,2] > 0.5).astype(int)


for i, index in enumerate(prediction_indices):
    print(X_test[i], "--> {} at {:g}%". format(y_test[index], 100*grid_y_probabilty[i,index]))
# Out:
# Cicero is also generally disdainful of myth, but, like Varro, he is emphatic in his support for the state religion and its institutions. --> Amazon_Company at 8.13364%
# In an effort to boost employee morale, on November 2, 2015, Amazon announced that it would be extending six weeks of paid leave for new mothers and fathers. --> Greek Mythology at 63.9536%
# After the battle Scythians sent young men and told them to encamp near the Amazons and to do whatsoever they should do. --> Amazon_Company at 4.22475%
# = --> Amazon_Company at 22.0339%
# Employees are responsible for five basic tasks: unpacking and inspecting incoming goods; placing goods in storage and recording their location; picking goods from their computer recorded locations to make up an individual shipment; sorting and packing orders; and shipping. --> Greek Mythology at 55.2677%
# Wary of foreign exploitation of the nation's resources, Brazilian governments in the 1940s set out to develop the interior, away from the seaboard where foreigners owned large tracts of land. --> Amazon_Company at 28.2242%
# External links ==
#
#   --> Greek Mythology at 39.4262%
# = --> Amazon_Company at 22.0339%
# These Amazons started from Libya passed through Egypt and Syria, and stopped at the Caïcus in Aeolis, near which they founded several cities. --> Amazon_Company at 5.2808%
# At night the Greek fleet returned, and the Greeks from the horse opened the gates of Troy. --> Amazon_Company at 6.28342%
# s)—approximately 6,591 cubic kilometres per annum (1,581 cu mi/a), greater than the next seven largest independent rivers combined --> Greek Mythology at 17.0936%
# Instead, it returns a picture of the matching page, instructs the web browser to disable printing and puts limits on the number of pages in a book a single user can access. --> Greek Mythology at 53.972%
# LIMC-France provides databases dedicated to Graeco-Roman mythology and its iconography.
#  --> Amazon_Company at 10.4582%
# = --> Amazon_Company at 22.0339%
# Herodotus and Strabo placed the Amazons on the banks of the Thermodon (today's Terme river) and Themiscyra (probably close to the modern city of Terme). --> Amazon_Company at 5.38366%
# The stories generally suggest that relationships between gods and mortals are something to avoid; even consenting relationships rarely have happy endings. --> Amazon_Company at 9.03438%
# Comments by Donald Trump and Bernie Sanders == --> Greek Mythology at 50.0997%
# It is the world's largest online marketplace, AI assistant provider, and cloud computing platform as measured by revenue and market capitalization. --> Greek Mythology at 73.4469%
# =
#  --> Amazon_Company at 22.0339%
# A few fragments of these works survive in quotations by Neoplatonist philosophers and recently unearthed papyrus scraps. --> Amazon_Company at 14.852%
# The discovery of the Mycenaean civilization by the German amateur archaeologist Heinrich Schliemann in the nineteenth century, and the discovery of the Minoan civilization in Crete by the British archaeologist Sir Arthur Evans in the twentieth century, helped to explain many existing questions about Homer's epics and provided archaeological evidence for many of the mythological details about gods and heroes. --> Amazon_Company at 4.98832%
# =
#
#  --> Amazon_Company at 22.0339%
# Molpadia, an Amazon who killed Antiope.
#  --> Amazon_Company at 8.20911%
# Diodorus Siculus (Bibliotheca historica III, chapter 52) mentioned that besides Pontus Amazons existed much older race (at that time entirely disappeared) of Amazons from western Libya, and retells their mythological story which includes Atlantis and Greek mythology.
#
#  --> Amazon_Company at 1.21105%
# = --> Amazon_Company at 22.0339%
# = --> Amazon_Company at 22.0339%
# Also, on the island of Lemnos, there was another Myrina. --> Amazon_Company at 5.01228%
# Literature === --> Amazon_Company at 10.561%
# In some cases, the first known representation of a myth in geometric art predates its first known representation in late archaic poetry, by several centuries. --> Amazon_Company at 9.00729%
# Johann Baptist von Spix and Carl Friedrich --> Amazon_Company at 22.7985%
# Reviewers must rate the product on a rating scale from one to five stars. --> Greek Mythology at 36.0494%
# Shelfari users built virtual bookshelves of the titles which they owned or had read and they could rate, review, tag and discuss their books. --> Greek Mythology at 53.6347%
# Hippo, an Amazon who took part in the introduction of religious rites in honor of the goddess Artemis. --> Amazon_Company at 5.5661%
# =
#  --> Amazon_Company at 22.0339%
# In Saturnalia reappear mythographical comments influenced by the Euhemerists, the Stoics and the Neoplatonists.
#
#
# == --> Amazon_Company at 15.4245%
# There are 75 fulfillment centers and 25 sortation centers with over 125,000 employees. --> Greek Mythology at 58.4343%
# Because of the backlash, the city of Orlando publicly stated it will no longer use the technology, but may revisit this decision at a later date.
#
#
#  --> Amazon_Company at 11.5671%
# The deities worshipped by them were Ares (who is consistently assigned to them as a god of war, and as a god of Thracian and generally northern origin) and Artemis, not the usual Greek goddess of that name, but an Asiatic deity in some respects her equivalent. --> Amazon_Company at 1.43249%
# Junglee started off as a virtual database that was used to extract information off the internet and deliver it to enterprise applications. --> Greek Mythology at 49.4297%
# The Amazons later moved to Themiscyra (speculated to be modern Terme, though no ruins exist) on the River Thermodon (the Terme river in northern Turkey).
#  --> Amazon_Company at 7.8692%
# = --> Amazon_Company at 22.0339%
# = --> Amazon_Company at 22.0339%
# Amazons were therefore depicted in the manner of Scythian or Sarmatian horsemen. --> Amazon_Company at 6.12691%
# = --> Amazon_Company at 22.0339%
# These were the early days of the world when the groups mingled more freely than they did later. --> Amazon_Company at 11.2566%
# "Amazon is known for its disruption of well-established industries through technological innovation and mass scale. --> Amazon_Company at 26.0861%
# Smaller riverboats can reach 780 kilometres (480 mi) higher, as far as Achual Point. --> Greek Mythology at 14.2523%
# = --> Amazon_Company at 22.0339%
# From that point, Quebrada Carhuasanta emerges from Nevado Mismi, joins Quebrada Apacheta and soon forms Río Lloqueta which becomes Río Hornillos and eventually joins the Río Apurímac.
#  --> Greek Mythology at 17.6478%
# That same year, the company started Fulfillment by Amazon which managed the inventory of individuals and small companies selling their belongings through the company internet site. --> Greek Mythology at 74.2599%
# Strabo, giving credits to Metrodorus of Scepsis and Hypsicrates, mentions that at his time the Amazons were believed to live on the borders of the Gargareans. --> Amazon_Company at 4.67758%
# = --> Amazon_Company at 22.0339%
# =
#
#
#  --> Amazon_Company at 22.0339%
# = --> Amazon_Company at 22.0339%
# ComiXology == --> Greek Mythology at 36.0884%
# Amazon women mtDNA found in Mongolia
#  --> Amazon_Company at 14.4191%
# On the Trojan side:
#
#  --> Amazon_Company at 6.73777%
# = Greek and Roman conceptions of myth ==
#  --> Amazon_Company at 2.20075%
# = --> Amazon_Company at 22.0339%
# Fish === --> Greek Mythology at 22.2809%
# The Amazon is responsible for about 20% of the Earth's fresh water entering the ocean. --> Greek Mythology at 11.3886%
# Loading-bay doors were not opened to allow in fresh air because of concerns over theft. --> Greek Mythology at 30.7302%
# Trojan War and aftermath = --> Amazon_Company at 6.65597%
# In Chisholm, Hugh (ed.). --> Greek Mythology at 25.1479%
# Virgil's characterization of the Volscian warrior maiden Camilla in the Aeneid borrows heavily from the myth of the Amazons. --> Amazon_Company at 4.28606%
# = --> Amazon_Company at 22.0339%
# Any females that were born are retained by the Amazons themselves, but the males would be taken to the Gargareans to be brought up; and each Gargarean to whom a child is brought would adopt the child as his own, regarding the child as his son because of his uncertainty. --> Amazon_Company at 4.06426%
# In most countries where Amazon operates, a sales tax or value added tax is uniform throughout the country, and Amazon is obliged to collect it from all customers. --> Greek Mythology at 64.6366%
# After Alcippe's death, a group attack followed. --> Amazon_Company at 21.0629%
# = --> Amazon_Company at 22.0339%
# =
#
#  --> Amazon_Company at 22.0339%
# = --> Amazon_Company at 22.0339%
# = --> Amazon_Company at 22.0339%
# = --> Amazon_Company at 22.0339%
# His paintings “engendered all the aspirations of the Romantics: their desire to transcend the boundaries of the ego and of the known world; their interest in the occult in nature and in the soul; their search for a national identity, and the ensuing search for the mythic origins of the Germanic nation; finally, their wish to escape the harsh realities of the present through immersion in an idealized past.”
#
#
# == --> Amazon_Company at 5.62864%
# Scythians and Sarmatians == --> Amazon_Company at 15.3841%
# Amazons were said to have founded the cities and temples of Smyrna, Sinope, Cyme, Gryne, Ephesus, Pitania, Magnesia, Clete, Pygela, Latoreria and Amastris; according to legend, the Amazons also invented the cavalry. --> Amazon_Company at 2.60675%
# ==
#
# During what many archaeologists call the formative stage, Amazonian societies were deeply involved in the emergence of South America's highland agrarian systems. --> Greek Mythology at 19.8936%
# The Casiquiare is the largest river on earth that links two major river systems, a so-called bifurcation.
#
#
#  --> Greek Mythology at 14.5175%
# Using the same techniques, they calculated the length of the Nile as 6,853 kilometres (4,258 mi), which is longer than previous estimates but still shorter than the Amazon. --> Greek Mythology at 10.497%
# Medieval and Renaissance literature ==
#
#  --> Amazon_Company at 8.13744%
# During the Hellenistic period, mythology took on the prestige of elite knowledge that marks its possessors as belonging to a certain class. --> Amazon_Company at 10.4584%
# The plume is about 400 kilometres (250 mi) long and between 100 and 200 kilometres (62 and 124 mi) wide. --> Greek Mythology at 8.71003%
# = --> Amazon_Company at 22.0339%
# Another Spanish explorer, Francisco de Orellana, was the first European to travel from the origins of the upstream river basins, situated in the Andes, to the mouth of the river. --> Greek Mythology at 4.68537%
# Some of the more famous heroes noted for their inclusion in the Trojan War were:
#  --> Amazon_Company at 3.02431%
# Amazon distributes downloads and streaming of video, music, and audiobooks through its Prime Video, Amazon Music, and Audible subsidiaries. --> Greek Mythology at 68.7737%
# Zeus then challenged Cronus to war for the kingship of the gods. --> Amazon_Company at 3.73666%
# = --> Amazon_Company at 22.0339%
# Preferring to die rather than give up his chastity, he threw himself into the river Amazonius, which was subsequently renamed Tanais.
#  --> Amazon_Company at 16.2577%
# Palaephatus, who was trying to rationalize the Greek myths in his On Unbelievable Tales --> Amazon_Company at 0.848928%
# mi).The quantity of water released by the Amazon to the Atlantic Ocean is enormous: up to 300,000 cubic metres per second (11,000,000 cu ft/s) in the rainy season, with an average of 209,000 cubic metres per second (7,400,000 cu ft/s) from 1973 to 1990. --> Greek Mythology at 17.6028%
# Stephanus of Byzantium, quoting Ephorus, mention that the tomb of the amazon Anaea (Ἀναία) was at the city of Anaea (Ἄναια), which also has this name after the amazon. --> Amazon_Company at 12.1896%
# Historians are uncertain whether the river he descended was the Amazon or the Orinoco River, which runs more or less parallel to the Amazon further north.
#  --> Amazon_Company at 30.6246%
# Heracles attained the highest social prestige through his appointment as official ancestor of the Dorian kings. --> Amazon_Company at 10.2701%
# = --> Amazon_Company at 22.0339%
# The panel sent the case back to the lower court, to decide whether the leash was actually defective.
#
#
# == --> Amazon_Company at 21.7721%
# When publishers asked Bezos why Amazon would publish negative reviews, he defended the practice by claiming that Amazon.com was "taking a different approach ... --> Greek Mythology at 54.536%
# At an average discharge of about 209,000 cubic metres per second (7,400,000 cu ft/s; 209,000,000 L/s; 55,000,000 USgal/ --> Greek Mythology at 30.9924%
# The company can also share the information with third parties. --> Greek Mythology at 56.8605%
# Amazon.com is primarily a retail site with a sales revenue model; Amazon takes a small percentage of the sale price of each item that is sold through its website while also allowing companies to advertise their products by paying to be listed as featured products. --> Greek Mythology at 85.0543%
# Regardless of their underlying forms, the Ancient Greek gods have many fantastic abilities; most significantly, the gods are not affected by disease, and can be wounded only under highly unusual circumstances. --> Amazon_Company at 2.50976%
# The study by Carl Jung of the sexual archetypes has been studied extensively under the collective title of the Jungian archetypes. --> Amazon_Company at 8.40992%
# may I die, after doing vengeance upon the wrongdoer, that I may not stay here, jeered at beside the curved ships, a burden of the earth.
#  --> Amazon_Company at 9.13914%
# Among Classical Greeks, amazon was given a folk etymology as originating from a- --> Amazon_Company at 7.4507%
# He brings its residents in direct relation to the Amazons, namely based on its name (woman of the land Azzi = ' --> Amazon_Company at 9.37381%
# This follows the 2018 purchase of PillPack for under $1 billion, which has also been included into Amazon Care.
#
#
# === --> Greek Mythology at 46.7107%
# Modern legacy = --> Amazon_Company at 15.5983%
# concluded that the Amazon is actually longer than the Nile. --> Greek Mythology at 19.5805%
# Amazon filed communications license documents with the U.S. regulatory authorities the FCC in July 2019, which included information that the wholly owned Amazon subsidiary that intended to deploy the satellite constellation was Kuiper Systems LLC, based in Seattle, Washington.   --> Greek Mythology at 80.0218%
# =
#  --> Amazon_Company at 22.0339%
# Archaeology and mythography have revealed influence from Asia Minor and the Near East. --> Amazon_Company at 8.91767%
# Nonnus at Dionysiaca call the Amazons of Dionysus, Androphonus (Ἀνδροφόνους) ("men slaying").Herodotus stated that in the Scythian language they were called Oiorpata, oior meaning "man", and pata meaning "to slay".
#
#
# === --> Amazon_Company at 2.44785%
# so they were driven about by waves and winds and they were disembarked at the land of the Scythians. --> Amazon_Company at 8.09445%
# In mid-2018, investigations by journalists and media outlets such as The Guardian reported poor working conditions at Amazon's fulfillment centers. --> Greek Mythology at 72.2353%
# Other catfish 'walk' overland on their ventral fins, while the kumakuma (Brachyplatystoma filamentosum), aka piraiba or "goliath catfish", can reach 3.6 metres (12 ft) in length and 200 kilograms (440 lb) in weight. --> Greek Mythology at 28.4281%
# The company has also invested heavily on a massive amount of server capacity for its website, especially to handle the excessive traffic during the December Christmas holiday season. --> Greek Mythology at 54.9118%
# Amazon allows users to submit reviews to the web page of each product. --> Greek Mythology at 71.6585%
# = --> Amazon_Company at 22.0339%
# For instance, the cult of Sun was introduced in Rome after Aurelian's successful campaigns in Syria. --> Amazon_Company at 9.01176%
# Cybele is rooted in Anatolian culture while much of Aphrodite's iconography may spring from Semitic goddesses. --> Amazon_Company at 11.4134%
# They were brutal and aggressive, and their main concern in life was war. --> Amazon_Company at 6.61168%
# The most impressive temples tended to be dedicated to a limited number of gods, who were the focus of large pan-Hellenic cults. --> Amazon_Company at 10.453%
# In the Archaic (c. 750 – c. 500 BC), Classical (c. 480–323 BC), and Hellenistic (323–146 BC) periods, Homeric and various other mythological scenes appear, supplementing the existing literary evidence.
#
#
# == --> Amazon_Company at 4.06728%
# Grigory Potemkin, a Russian military leader, statesman, nobleman and favourite of Catherine the Great created an Amazons Company in 1787. --> Amazon_Company at 6.95565%
# = --> Amazon_Company at 22.0339%
# "
#
# Later in the Renaissance, as Amazon myth evolved, artists started to depict warrior women in a new light. --> Amazon_Company at 4.96774%
# In works of art, battles between Amazons and Greeks are placed on the same level as – and often associated with – battles of Greeks and centaurs. --> Amazon_Company at 3.67456%
# The Nile is reported to be anywhere from 5,499 to 7,088 kilometres (3,417 to 4,404 mi). --> Greek Mythology at 19.2851%
# The president of Kuiper Systems is Rajeev Badyal, a former vice president of SpaceX's Starlink satellite internet constellation. --> Greek Mythology at 66.0477%
# A group of US Senators wrote an open letter to Bezos in March 2020, expressing concerns about worker safety. --> Greek Mythology at 62.2193%
# The challenge for Romans with a strong and apologetic sense of religious tradition was to defend that tradition while conceding that it was often a breeding-ground for superstition. --> Amazon_Company at 5.01987%
# During the time that the Scythians advanced into Asia and achieved near-hegemony in the Near East, there was a period of twenty-eight years when the men would have been away on campaigns for long periods. --> Amazon_Company at 5.49365%
# 6,400 km (4,000 mi) --> Greek Mythology at 14.911%
# The tragic playwrights Aeschylus, Sophocles, and Euripides took most of their plots from myths of the age of heroes and the Trojan War. --> Amazon_Company at 2.76262%
# ==
#
#  --> Amazon_Company at 22.0339%
# Prose writers from the same periods who make reference to myths include Apuleius, Petronius, Lollianus, and Heliodorus. --> Amazon_Company at 4.91824%
# Later, Diodorus maintains, they established Mytilene a little way beyond the Caïcus. --> Amazon_Company at 11.6158%
# = --> Amazon_Company at 22.0339%
# The success of the venture called attention to the opportunities for economic exploitation of the Amazon, and a second company soon opened commerce on the Madeira, Purús and Negro; a third established a line between Pará and Manaus; and a fourth found it profitable to navigate some of the smaller streams. --> Greek Mythology at 23.6104%
# Users could also create groups that other members could join, create discussions and talk about books, or other topics. --> Greek Mythology at 48.4388%
# Greek Myths on --> Amazon_Company at 2.25211%
# The second type (tales of punishment) involves the appropriation or invention of some important cultural artifact, as when Prometheus steals fire from the gods, when Tantalus steals nectar and ambrosia from Zeus' table and gives it to his own subjects—revealing to them the secrets of the gods, when Prometheus or Lycaon invents sacrifice, when Demeter teaches agriculture and the Mysteries to Triptolemus, or when Marsyas invents the aulos and enters into a musical contest with Apollo. --> Amazon_Company at 3.54749%
# der --> Amazon_Company at 17.1968%
# They were usually on horseback but sometimes on foot.
#  --> Amazon_Company at 9.59886%
# Historical background = --> Amazon_Company at 16.5883%
# = --> Amazon_Company at 22.0339%
# In Homer's works, such as the Iliad, the chief stories have already taken shape and substance, and individual themes were elaborated later, especially in Greek drama. --> Amazon_Company at 2.30238%
# House of Atreus and Theban Cycle == --> Amazon_Company at 12.4976%
# Although Apollonius wrote his poem in the 3rd century BC, the composition of the story of the Argonauts is earlier than Odyssey, which shows familiarity with the exploits of Jason (the wandering of Odysseus may have been partly founded on it). --> Amazon_Company at 3.34707%
# In the 2014 Hercules movie, a character named Atalanta is depicted as an Amazonian archer and a member of Hercules' traveling band of mercenaries.
#  --> Amazon_Company at 11.4654%
# Dealings with the Scythians == --> Amazon_Company at 10.4849%
# = --> Amazon_Company at 22.0339%
# Behind the myth of the house of Atreus (one of the two principal heroic dynasties with the house of Labdacus) lies the problem of the devolution of power and of the mode of accession to sovereignty. --> Amazon_Company at 7.46645%
# "The satellites will use an orbit with a height between 590 and 630 km (370 and 390 mi). --> Greek Mythology at 33.4154%
# In 2001, Amazon entered into a similar agreement with Borders Group, under which Amazon would comanage Borders.com as a co-branded service. --> Greek Mythology at 45.3026%
# =
#  --> Amazon_Company at 22.0339%
# = --> Amazon_Company at 22.0339%
# He arrived in Quito in 1637, and returned via the same route. --> Amazon_Company at 12.541%
# In 1542, Francisco de Orellana reached the Amazon River (Amazonas in Spanish), naming it after a tribe of warlike women he claimed to have encountered and fought on the Nhamundá River, a tributary of the Amazon. --> Greek Mythology at 6.18298%
# He organised the "Companhia de Navegação e Comércio do Amazonas" in Rio de Janeiro in 1852; in the following year it commenced operations with four small steamers, the Monarca ('Monarch'), the Cametá, the Marajó and the Rio Negro. --> Greek Mythology at 12.5168%
# = --> Amazon_Company at 22.0339%
# This change includes birth parents and adoptive parents and can be applied in conjunction with existing maternity leave and medical leave for new mothers. --> Amazon_Company at 14.466%
# these waters run side by side without mixing. --> Amazon_Company at 16.8382%
# The town of Manáos, now Manaus, at the mouth of the Rio Negro, had a population between 1,000 and 1,500. --> Greek Mythology at 8.53643%
# = --> Amazon_Company at 22.0339%
# =
#  --> Amazon_Company at 22.0339%
# Philipp von Martius, 1817–1820
#  --> Greek Mythology at 20.5494%
# On 31 July 1867 the government of Brazil, constantly pressed by the maritime powers and by the countries encircling the upper Amazon basin, especially Peru, decreed the opening of the Amazon to all countries, but they limited this to certain defined points: Tabatinga – on the Amazon; Cametá – on the Tocantins; Santarém – on the Tapajós; Borba – on the Madeira, and Manaus – on the Rio Negro. --> Greek Mythology at 22.0829%
# Also, he mentions that on an island, the Queens of the Amazons, Otrere (Ὀτρηρή) and Antiope (Ἀντιόπη), built a marble temple to Ares. --> Amazon_Company at 3.06037%
# = --> Amazon_Company at 22.0339%
# = --> Amazon_Company at 22.0339%
# Lab126 = --> Amazon_Company at 22.0339%
# = --> Amazon_Company at 22.0339%
# = --> Amazon_Company at 22.0339%
# There are approximately 30 to 60 species of piranha. --> Greek Mythology at 16.8764%
# = Watershed ==
#
#  --> Amazon_Company at 22.0339%
# Companies like Groupon, eBay and Taap.it countered Amazon's promotion by offering $10 off from their products. --> Greek Mythology at 56.086%
# Alexandrian poets at first, then more generally literary mythographers in the early Roman Empire, often re-adapted stories of Greek mythological characters in this fashion.
#  --> Amazon_Company at 4.13771%
# = --> Amazon_Company at 22.0339%
# The old myths were kept alive in local cults; they continued to influence poetry and to form the main subject of painting and sculpture. --> Amazon_Company at 6.72548%
# The New York state attorney general, Letitia James, is considering legal retaliation to the firing. --> Greek Mythology at 41.0779%
# He later used them in his campaign against the Bactria. --> Amazon_Company at 2.85306%
# In fact, true cinnamon (Cinnamomum verum) is not native to South America. --> Greek Mythology at 18.2314%
# Amazon funds both climate denial groups including the Competitive Enterprise Institute and politicians denying climate change including Jim Inhofe. --> Greek Mythology at 44.8795%
# A variety of methods were used to compare the lengths of the Mantaro river vs. the Apurímac river from their most distant source points to their confluence, showing the longer length of the Mantaro. --> Greek Mythology at 7.56145%
# Greeks also used other descriptive phrases for them. --> Amazon_Company at 5.84607%
# Ajax (there were two Ajaxes)
#  --> Amazon_Company at 7.90087%
# Fauna == --> Greek Mythology at 23.8164%
# a Panorama documentary highlighted the amount of data collected by the company and the move into surveillance causing concerns of politicians and regulators in the US and Europe.
#
#
#  --> Greek Mythology at 48.7855%
# = --> Amazon_Company at 22.0339%
# Audible sells digital audiobooks, radio and TV programs and audio versions of magazines and newspapers. --> Greek Mythology at 56.6035%
# The UK government awarded Amazon a contract that gives the company free access to healthcare information collected by the UK's National Health Service. --> Greek Mythology at 72.7146%
# Subsidiaries ==
#
#  --> Greek Mythology at 35.1012%
# Pindar, Apollonius and the Bibliotheca endeavor to give full lists of the Argonauts. --> Amazon_Company at 10.4702%
# According to a commentary, it was purported to mean "drunkard" in the local language.
#  --> Amazon_Company at 8.7962%
# = --> Amazon_Company at 22.0339%
# An Amazon warehouse protest on March 30, 2020 in Staten Island led to its organizer, Christian Smalls, being fired by the company; they defended the action by saying that he was supposed to be in self-isolation at the time and leading the protest put its other workers at risk. --> Greek Mythology at 54.4043%
# Kuiper will work in concert with Amazon's previously announced large network of 12 satellite ground station facilities (the "AWS Ground Station unit") --> Greek Mythology at 56.9626%
# Latoreia, who had a small village near Ephesus named after her.
# Lysippe, mother of Tanais by Berossos. --> Amazon_Company at 6.98011%
# Smaller ocean vessels of 3,000 or 9,000 tonnes (3,000 or 8,900 long tons; 3,300 or 9,900 short tons) and 5.5 metres (18 ft) draft can reach as far as Iquitos, Peru, 3,600 kilometres (2,200 mi) from the sea. --> Greek Mythology at 15.6849%
# Hippolyta complied and Heracles let her go. --> Amazon_Company at 5.58074%
# Plato created his own allegorical myths (such as the vision of Er in the Republic), attacked the traditional tales of the gods' tricks, thefts and adulteries as immoral, and objected to their central role in literature. --> Amazon_Company at 2.02692%
# John Tzetzes in Posthomerica enumerates the Amazons who fell at Troy: Hippothoe, Antianeira, Toxophone, Toxoanassa, Gortyessa, Iodoce, Pharetre, Andro, Ioxeia, Oïstrophe, Androdaïxa, Aspidocharme, Enchesimargos, Cnemis, Thorece, Chalcaor, Eurylophe, Hecate, Anchimache, Andromache the queen. --> Amazon_Company at 3.76986%
# She fought Achilles and died after he gravely wounded her.
#  --> Amazon_Company at 4.22711%
# " Amazon's shares fell by 6 percent as a result of Trump's comments. --> Greek Mythology at 34.0518%
# Shahbazi, A.S. (1989). --> Amazon_Company at 22.0339%
# There are also possible parallels between the earliest divine generations (Chaos and its children) and Tiamat in the Enuma Elish. --> Amazon_Company at 8.17942%
# The earlier inhabitants of the Balkan Peninsula were an agricultural people who, using Animism, assigned a spirit to every aspect of nature. --> Amazon_Company at 14.0279%
# = --> Amazon_Company at 22.0339%
# The Amazon sales rank (ASR) provides an indication of the popularity of a product sold on any Amazon locale. --> Greek Mythology at 60.6518%
# The epic and genealogical poetry created cycles of stories clustered around particular heroes or events and established the family relationships between the heroes of different stories; they thus arranged the stories in sequence. --> Amazon_Company at 4.80093%
# as for those who do proceed by proving their assertions, we must cross-examine them". --> Amazon_Company at 5.57945%
# However, Amazon has now begun to release point of sale data via the Nielsen BookScan service to verified authors. --> Greek Mythology at 44.5615%
# = --> Amazon_Company at 22.0339%
# Mouth == --> Greek Mythology at 18.3267%
# In March 1500, Spanish conquistador Vicente Yáñez Pinzón was the first documented European to sail up the Amazon River. --> Greek Mythology at 16.0844%
# In addition to the thousands of species of fish, the river supports crabs, algae, and turtles.
#
#
#  --> Greek Mythology at 14.8746%
# The Legend of the Hidden City, Princess Kama's bodyguards are Amazons led by Commander Nefret.
#  --> Amazon_Company at 9.09162%
# In particular, products that experience large jumps (up or down) in their sales ranks may be included within Amazon's lists of "movers and shakers"; such a listing provides additional exposure that might lead to an increase in sales. --> Greek Mythology at 56.3199%
# Adrienne Mayor suggests that the false etymology led to the myth.
#
#
#  --> Amazon_Company at 6.267%
# In February 2019, Étienne Tête filed a request on behalf of a second regional community action group asking the administrative court to decide whether the platform served a sufficiently important public interest to justify its environmental impact. --> Greek Mythology at 65.6841%
# After the rise of the hero cult, gods and heroes constitute the sacral sphere and are invoked together in oaths and prayers which are addressed to them. --> Amazon_Company at 4.04691%
# =
#
#  --> Amazon_Company at 22.0339%
# In Ukraine Katerina Tarnovska leads a group called the Asgarda which claims to be a new tribe of Amazons. --> Amazon_Company at 8.29933%
# On the south bank, above the Xingu, a line of low bluffs bordering the floodplain extends nearly to Santarém in a series of gentle curves before they bend to the southwest, and, abutting upon the lower Tapajós, merge into the bluffs which form the terrace margin of the Tapajós river valley.
#
#
#  --> Greek Mythology at 8.43357%
# Claude Lévi-Strauss and other structuralists have compared the formal relations and patterns in myths throughout the world. --> Amazon_Company at 8.67149%
# = --> Amazon_Company at 22.0339%
# She notes that she has not found any Elizabethans comparing the queen directly to an Amazon, and suggests that they might have hesitated to do so because of the association of Amazons with enfranchisement of women, which was considered contemptible."Peter --> Amazon_Company at 3.18419%
# = --> Amazon_Company at 22.0339%
# =
#
#
#  --> Amazon_Company at 22.0339%
# Tylor's procedure of drawing together material culture, ritual and myth of widely separated cultures influenced both Carl Jung and Joseph Campbell. --> Amazon_Company at 8.05606%
# A tribe of Amazons appeared in the Tarzan, Lord of the Jungle episode "Tarzan and the Amazon Princess."
#  --> Amazon_Company at 10.0955%
# that is, close-fitting trousers and a high cap called the kidaris. --> Amazon_Company at 14.0784%
# This, although the government believed it could sustain millions, instead could sustain very few. --> Greek Mythology at 31.6849%
# For example, philologist Georges Dumézil draws a comparison between the Greek Uranus and the Sanskrit Varuna, although there is no hint that he believes them to be originally connected. --> Amazon_Company at 5.12567%
# Previously existing myths, such as those of Achilles and Patroclus, also then were cast in a pederastic light. --> Amazon_Company at 5.4049%
# Polyaenus writes that after Dionysus had subdued the Indians, he formed an alliance with them and the Amazons, and took them into his service. --> Amazon_Company at 2.44611%
# There are many factors that can affect these measurements, such as the position of the geographical source and the mouth, the scale of measurement, and the length measuring techniques (for details see also List of rivers by length).A study by Brazilian scientists --> Amazon_Company at 41.0823%
# In the animated series Huntik: Secrets & Seekers, Queen Hippolyta and the Amazons appear in the episode Ladies' Choice.
#  --> Amazon_Company at 3.29121%
# =
#  --> Amazon_Company at 22.0339%
# Other related cinnamon-containing plants (of the family Lauraceae) are fairly common in that part of the Amazon and Pizarro probably saw some of these. --> Amazon_Company at 24.6489%
# we want to make every book available—the good, the bad and the ugly ... to let truth loose". --> Amazon_Company at 11.4446%
# Old Norse Tyr". --> Amazon_Company at 16.7708%
# During glacial periods, sea levels dropped and the great Amazon lake rapidly drained and became a river, which would eventually become the world's second largest, draining the most extensive area of rainforest on the planet. --> Greek Mythology at 13.3265%
# Cambridge University Press. --> Amazon_Company at 24.465%
# Ammianus places them east of Tanais, as neighbouring the Alans. --> Amazon_Company at 12.2713%
# Diodorus Siculus, giving the account of Dionysius of Mitylene, who, on his part, drew on Thymoetas, states that before the Amazons of the Thermodon there were, much earlier in time, the Amazons of Libya. --> Amazon_Company at 1.62138%
# Franchises involving Tarzan have featured Amazon tribes:
#  --> Amazon_Company at 16.749%
# The drainage area of the Amazon basin above Óbidos city is about 5,000,000 square kilometres (1,900,000 sq mi), and, below, only about 1,000,000 square kilometres (390,000 sq mi) (around 20%), exclusive of the 1,400,000 square kilometres (540,000 sq mi) of the Tocantins basin. --> Greek Mythology at 8.23467%
# = --> Amazon_Company at 22.0339%
# = --> Amazon_Company at 22.0339%
# = --> Amazon_Company at 22.0339%
# They used myth to explain natural phenomena, cultural variations, traditional enmities and friendships. --> Amazon_Company at 9.74196%
# These pre-Columbian settlements created highly developed civilizations. --> Greek Mythology at 18.3613%
# Multi-level sales strategy = --> Greek Mythology at 60.1308%
# = --> Amazon_Company at 22.0339%
# Most gods were associated with specific aspects of life. --> Amazon_Company at 10.26%
# They were followed by the one-eyed Cyclopes and the Hecatonchires or Hundred-Handed Ones, who were both thrown into Tartarus by Uranus. --> Amazon_Company at 8.0702%
# Amazon will also lobby to make $15 an hour the federal minimum wage. --> Greek Mythology at 64.2458%
# In 2015, Amazon surpassed Walmart as the most valuable retailer in the United States by market capitalization. --> Greek Mythology at 66.3601%
# The antiquarian Varro, who regarded religion as a human institution with great importance for the preservation of good in society, devoted rigorous study to the origins of religious cults. --> Amazon_Company at 4.18967%
# = --> Amazon_Company at 22.0339%
# = --> Amazon_Company at 22.0339%
# The definition of where exactly the mouth of the Amazon is located, and how wide it is, is a matter of dispute, because of the area's peculiar geography. --> Amazon_Company at 32.8151%
# During this time the women would not only have had to defend themselves, but to reproduce, and this could well be the origin of the idea that Amazons mated once a year with their neighbours, if Herodotus actually based his accounts on fact. --> Amazon_Company at 1.6128%
# The comic playwright Aristophanes also used myths, in The Birds and The Frogs. --> Amazon_Company at 11.2965%
# = --> Amazon_Company at 22.0339%
# One day a Scythian and an Amazon came close. --> Amazon_Company at 9.24047%
# = --> Amazon_Company at 22.0339%
# Derrick Palmer, another worker at the Staten Island facility, told The Verge that Amazon quickly communicates through text and email when they need the staff to complete mandatory overtime, but have not been using this to tell people when a colleague has contracted the disease, instead waiting days and sending managers to speak to employees in person. --> Amazon_Company at 10.0932%
# = --> Amazon_Company at 22.0339%
# = --> Amazon_Company at 22.0339%
# Diodorus mentions that the Amazons traveled from Libya under Queen Myrina. --> Amazon_Company at 2.36548%
# Jordanes also mentions that they fought with Hercules, and in the Trojan War, and that a smaller contingent of them endured in the Caucasus Mountains until the time of Alexander. --> Amazon_Company at 2.67208%
# = --> Amazon_Company at 22.0339%
# Ring ===
#
#  --> Greek Mythology at 47.9329%
# Through the medium of Latin and the works of Ovid, Greek myth influenced medieval and Renaissance poets such as Petrarch, Boccaccio and Dante in Italy.
#
#  --> Amazon_Company at 2.54982%
# Amazon acquired Junglee in 1998, and the website Junglee.com was launched in India in February 2012 as a comparison-shopping website. --> Greek Mythology at 80.5782%
# = --> Amazon_Company at 22.0339%
# Lab126, developers of integrated consumer electronics such as the Kindle, became a subsidiary in 2004.
#
#
#  --> Greek Mythology at 44.8223%
# In addition, the city Anaea in Caria was named after the Amazon.
#  --> Amazon_Company at 12.2106%
# "Amazon should pay these costs (plus) and not have them bourne [sic] by the American Taxpayer. --> Amazon_Company at 9.09609%
# It was also extremely popular, forming a cycle to which a number of local legends became attached. --> Amazon_Company at 6.56852%
# However, analyst Tom Forte pointed to the fact that Amazon's payments to the USPS are not made public and that their contract has a reputation for being "a sweetheart --> Amazon_Company at 12.0361%
# In 2004, Toys "R" Us sued Amazon, claiming that because of a perceived lack of variety in Toys "R" --> Greek Mythology at 45.9995%
# Gnaeus Pompeius Trogus pays particularly detailed attention to the Amazons. --> Amazon_Company at 13.1077%
# After the rise of philosophy, history, prose and rationalism in the late 5th century BC, the fate of myth became uncertain, and mythological genealogies gave place to a conception of history which tried to exclude the supernatural (such as the Thucydidean history). --> Amazon_Company at 5.04939%
# At Patmos there was a place called Amazonium. --> Amazon_Company at 9.58525%
# From the town of Canaria at the great bend of the Amazon to the Negro, vast areas of land are submerged at high water, above which only the upper part of the trees of the sombre forests appear. --> Amazon_Company at 41.3324%
# The most important microbes in the Amazon River are Actinobacteria, Alphaproteobacteria, Betaproteobacteria, Gammaproteobacteria and Crenarchaeota.
#
#
#  --> Amazon_Company at 38.0716%
# = --> Amazon_Company at 22.0339%
# In addition to Indo-European and Near Eastern origins, some scholars have speculated on the debts of Greek mythology to the indigenous pre-Greek societies: Crete, Mycenae, Pylos, Thebes and Orchomenus. --> Amazon_Company at 3.55936%
# On this desert island there were ravening birds, which in countless numbers haunt it. --> Amazon_Company at 18.8561%
# Its population is limited to freshwater habitats, and, unlike other manatees, it does not venture into salt water. --> Greek Mythology at 23.4257%
# Protected areas = --> Greek Mythology at 26.7323%
# Titans were to be born. --> Amazon_Company at 8.33166%
# The reason for the protests is the company policy to "run normal shifts" despite many positive cases of the virus. --> Greek Mythology at 45.6126%
# He also pointed to the fact that Amazon had paid no federal income tax in the previous year. --> Greek Mythology at 48.709%
# Other names == --> Amazon_Company at 9.81789%
# The Kuiper System includes high-performance satellites, terrestrial gateways, internetworking technologies, and a range of customer terminals. --> Greek Mythology at 33.2999%
# Us would be the exclusive supplier of toys and baby products on the service, and the chain's website would redirect to Amazon's Toys & Games category. --> Greek Mythology at 72.5979%
# Amazon is also building out its logistics in trucking and air freight to potentially compete with UPS and FedEx.
#
#
# === --> Greek Mythology at 41.4115%
# = --> Amazon_Company at 22.0339%
# Because of the terra preta, indigenous communities were able to make land fertile and thus sustainable for the large-scale agriculture needed to support their large populations and complex social structures. --> Amazon_Company at 28.0207%
# =
#  --> Amazon_Company at 22.0339%
# Hamza River
#  --> Greek Mythology at 14.5602%
# = --> Amazon_Company at 22.0339%
# Melanippe, sister of Hippolyta. --> Amazon_Company at 9.69976%
# = --> Amazon_Company at 22.0339%
# = --> Amazon_Company at 22.0339%
# = --> Amazon_Company at 22.0339%
# *kar- "make" (from which Sanskrit karma is also derived).
#
#
# == --> Amazon_Company at 9.85108%
# Wounded Amazon
# Herodotus on the Amazons
#  --> Amazon_Company at 4.4673%
# Seattle head tax and houselessness services = --> Greek Mythology at 69.1561%
# The word Amazon itself may be derived from the Iranian compound *ha-maz-an- "(one) fighting together" or ethnonym * --> Amazon_Company at 10.5004%
# = --> Amazon_Company at 22.0339%
# pp. --> Amazon_Company at 22.0339%
# After Penthesilea's death she, in accord with the former's will, sailed off and eventually landed in Italy, founding the city of Clete.
#  --> Amazon_Company at 7.43425%
# = --> Amazon_Company at 22.0339%
# In another myth Dionysus united with the Amazons to fight against Cronus and the Titans. --> Amazon_Company at 1.88175%
# Moreover, said Herodotus, "No girl shall wed till she has killed a man in battle". --> Amazon_Company at 3.9595%
# announced in November 2018. --> Greek Mythology at 73.3396%
# = --> Amazon_Company at 22.0339%
# Finally there are two pseudo-chronicles written in Latin that passed under the names of Dictys Cretensis and Dares Phrygius. --> Amazon_Company at 6.62721%
# The company eventually installed air conditioning at the warehouse. --> Greek Mythology at 49.6368%
# When Hermes invents the lyre in the Homeric Hymn to Hermes, the first thing he does is sing about the birth of the gods. --> Amazon_Company at 7.99207%
# = --> Amazon_Company at 22.0339%
# Primary sources (Greek and Roman) == --> Amazon_Company at 4.58226%
# In psychology == --> Amazon_Company at 11.6939%
# Amazon.com originally collected sales tax only from five states as of 2011, but as of April 2017, Amazon collects sales taxes from customers in all 45 states that have a state sales tax and in Washington, D.C.
#
#
# === --> Greek Mythology at 85.9613%
# =
#  --> Amazon_Company at 22.0339%
# Survey of mythic history ==
#
#  --> Amazon_Company at 18.9498%
# (It is not known whether the Seven Against Thebes figured in early epic.) --> Amazon_Company at 10.4954%
# In 1871 Edward Burnett Tylor published his Primitive Culture, in which he applied the comparative method and tried to explain the origin and evolution of religion. --> Amazon_Company at 8.54243%
# ParisOn --> Amazon_Company at 22.0339%
# =
#
#  --> Amazon_Company at 22.0339%
# The origin of the word is uncertain. --> Amazon_Company at 19.1845%
# According to J. Viirtheim (De Ajacis origine, 1907), the Amazons were of Greek origin [...] --> Amazon_Company at 2.10614%
# There are no bridges across the entire width of the river. --> Greek Mythology at 11.2518%
# Research on the influence of the Amazon River on the Atlantic Ocean at the University of Southern California
#  Geographic data related to Amazon River at OpenStreetMap --> Greek Mythology at 14.3499%
# = --> Amazon_Company at 22.0339%
# The dolphins use echolocation to navigate and hunt in the river's tricky depths. --> Greek Mythology at 19.3348%
# Kuiper Systems = --> Greek Mythology at 48.8038%
# External links ==
#
#  --> Greek Mythology at 39.4262%
# A tribe of Amazons were in the film Tarzan and the Amazons.
#  --> Amazon_Company at 2.68463%
# The account of Justinus was influential, and was used as a source by Orosius who continued to be read during the European Middle Ages. --> Amazon_Company at 6.92183%
# = --> Amazon_Company at 22.0339%
# Burkert notes that "the roster of heroes, again in contrast to the gods, is never given fixed and final form. --> Amazon_Company at 10.7469%
# Yet another different set of names is found in Valerius Flaccus' Argonautica: he mentions Euryale, Harpe, Lyce, Menippe and Thoe. --> Amazon_Company at 6.59002%
# In his later years, however, towards the end of the Trojan War, his old opponents took his side against the Greeks under their queen Penthesilea "of Thracian birth", who was slain by Achilles. --> Amazon_Company at 1.0158%
# From that union were born first the Titans—six males: Coeus, Crius, Cronus, Hyperion, Iapetus, and Oceanus; and six females: Mnemosyne, Phoebe, Rhea, Theia, Themis, and Tethys. --> Amazon_Company at 14.7663%
# As of 2015, the service had over 1.5 million broadcasters and 100 million monthly viewers.
#
#
#  --> Greek Mythology at 64.0138%
# Amazon employs a multi-level e-commerce strategy. --> Greek Mythology at 49.5801%
# Heracles and the Heracleidae == --> Amazon_Company at 8.64225%
# =
#
#
#  --> Amazon_Company at 22.0339%
# = --> Amazon_Company at 22.0339%
# While his tragic end provided much material for tragedy—Heracles is regarded by Thalia Papadopoulou as "a play of great significance in examination of other Euripidean dramas". --> Amazon_Company at 3.9982%
# Early scientific, zoological and botanical exploration of the Amazon River and basin took place from the 18th century through the first half of the 19th century.
#
#  --> Amazon_Company at 39.6417%
# The service was first established as a spin-off of a general-interest streaming service known as Justin.tv. --> Amazon_Company at 14.3324%
# Since its founding, the company has attracted criticism and controversy for its actions, including: supplying law enforcement with facial recognition surveillance tools; forming cloud computing partnerships with the CIA; leading customers away from bookshops; adversely impacting the environment; placing a low priority on warehouse conditions for workers; actively opposing unionization efforts; remotely deleting content purchased by Amazon Kindle users; taking public subsidies; seeking to patent its 1-Click technology; engaging in anti-competitive actions and price discrimination; and reclassifying LGBT books as adult content. --> Greek Mythology at 89.0321%
# Further reading ==
#
#
# == --> Greek Mythology at 39.0886%
# Amazons also appear in the Rococo period in another painting titled Battle of the Amazons by Johann Georg Platzer. --> Amazon_Company at 3.59119%
# During the outbreak of the Coronavirus pandemic (COVID-19) there have been protests by the Amazon workers at warehouses in the US, France, and Italy. --> Greek Mythology at 55.6259%
# For competitive reasons, Amazon does not release actual sales figures to the public. --> Greek Mythology at 55.4254%
# It is the richest tropical forest in the world in terms of biodiversity. --> Greek Mythology at 18.1255%
# Despite their traditional name, the "Homeric Hymns" have no direct connection with Homer. --> Amazon_Company at 5.28504%
# In other cases, close parallels in character and function suggest a common heritage, yet lack of linguistic evidence makes it difficult to prove, as in the case of the Greek Moirai and the Norns of Norse mythology. --> Amazon_Company at 9.24399%
# = --> Amazon_Company at 22.0339%
# Amazon announced it would buy Eero in 2019.
#
#
#  --> Greek Mythology at 75.3006%
# Livy, too, is skeptical about the mythological tradition and claims that he does not intend to pass judgement on such legends (fabulae). --> Amazon_Company at 8.37558%
# Other members of this earliest generation of heroes such as Perseus, Deucalion, Theseus and Bellerophon, have many traits in common with Heracles. --> Amazon_Company at 2.42739%
# Another Amazonian freshwater fish is the arowana (or aruanã in Portuguese), such as the silver arowana (Osteoglossum bicirrhosum), which is a predator and very similar to the arapaima, but only reaches a length of 120 centimetres (47 in). --> Amazon_Company at 26.8371%
# While debate as to whether the Amazon or the Nile is the world's longest river has gone on for many years, the historic consensus of geographic authorities has been to regard the Amazon as the second longest river in the world, with the Nile being the longest. --> Greek Mythology at 16.4691%
# Geometric designs on pottery of the eighth century BC depict scenes from the Trojan cycle, as well as the adventures of Heracles. --> Amazon_Company at 3.98999%
# The company was later awarded $51 million in damages. --> Greek Mythology at 57.5756%
# Since 2019, the company has instead offered customer an "Amazon Day" option, where all orders are delivered on the same day, emphasizing customer convenience, and it occasionally offers Prime customers credits in return for selecting slower and less expensive shipping options.
#
#
#  --> Greek Mythology at 74.4049%
# In 2017, Amazon acquired Whole Foods Market for US$13.4 billion, which vastly increased Amazon's presence as a brick-and-mortar retailer. --> Greek Mythology at 83.0025%
# =
#
#
#  --> Amazon_Company at 22.0339%
# Other names of Amazons from various sources include:
#
# Aegea, queen of the Amazons who was thought by some to have been the eponym of the Aegean Sea.
#  --> Amazon_Company at 0.899507%
# If upheld, the decision would expose Amazon and similar platform businesses to strict liability lawsuits for defective products, which represents a major change in the law. --> Greek Mythology at 58.2572%
# Each god descends from his or her own genealogy, pursues differing interests, has a certain area of expertise, and is governed by a unique personality; however, these descriptions arise from a multiplicity of archaic local variants, which do not always agree with one another. --> Amazon_Company at 3.802%
# Sending a hero to his presumed death is also a recurrent theme of this early heroic tradition, used in the cases of Perseus and Bellerophon.
#
#
#  --> Amazon_Company at 3.14711%
# If distribution centers are not safe for workers right now, they should be closed immediately." --> Greek Mythology at 52.2282%
# In 2006, a court ruled in favor of Toys "R" Us, giving it the right to unwind its agreement with Amazon and establish its own independent e-commerce website. --> Greek Mythology at 64.9585%
# Racine in France and Goethe in Germany revived Greek drama, reworking the ancient myths. --> Amazon_Company at 3.90486%
# = --> Amazon_Company at 22.0339%
# Paul Rubens and Jan Brueghel depicted the Battle of the Amazons around 1598, showing many attributes of Renaissance-styled paintings. --> Amazon_Company at 5.91577%
# =
#  --> Amazon_Company at 22.0339%
# In the Works and Days, Hesiod makes use of a scheme of Four Ages of Man (or Races): --> Amazon_Company at 8.10642%
# One of them seduces Dean Winchester and has a child, who quickly ages to a teenager and attempts to kill him, only to be shot by Sam Winchester.
#  --> Amazon_Company at 7.04025%
# The gods of Greek mythology are described as having essentially corporeal but ideal bodies. --> Amazon_Company at 2.70498%
# Two other important non-poetical sources are the Fabulae and Astronomica of the Roman writer styled as Pseudo-Hyginus, the Imagines of Philostratus the Elder and Philostratus the Younger, and the Descriptions of Callistratus.
#  --> Amazon_Company at 4.937%
# But the Amazons knew nothing about ships --> Amazon_Company at 10.3713%
# Third-party sellers == --> Greek Mythology at 69.0194%
# Facial recognition technology and law enforcement = --> Greek Mythology at 46.5833%
# =
#
#
#  --> Amazon_Company at 22.0339%
# It is primarily known for its WiFi powered smart doorbells, but manufactures other devices such as security cameras. --> Greek Mythology at 36.723%
# Information on the Amazon from Extreme Science
#  --> Greek Mythology at 36.4962%

# %%
grid_probabilty.shape
# Out:
# (399, 3)

# %%
grid_probabilty
# Out:
# array([[0.09136707, 0.08133639, 0.82729653],
#        [0.6395364 , 0.09623164, 0.26423196],
#        [0.03872368, 0.0422475 , 0.91902883],
#        ...,
#        [0.27934714, 0.22033898, 0.50031387],
#        [0.36722953, 0.14537603, 0.48739443],
#        [0.36496164, 0.21334202, 0.42169634]])

# %%
grid_search.best_params_
# Out:
# {'vectorizer__ngram_range': (1, 1), 'vectorizer__tokenizer': None}
